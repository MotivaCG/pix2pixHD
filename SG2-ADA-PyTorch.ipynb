# %% [markdown]
# # StyleGAN2-ADA-PyTorch
#
# ## Please Read
# This StyleGAN2-ADA-PyTorch repository (including this Colab notebook) was forked from [Derrick Schultz](https://github.com/dvschultz/stylegan2-ada-pytorch), which was forked from [Nvidia's original repo](https://github.com/NVlabs/stylegan2-ada-pytorch). A huge thank you to Derrick for developing these tools to make GANs accessible for artists and newcomers, and for generously sharing his knowledge and resources **for free**. Without artists/educators like this, we would be spending much more time (and money) getting these things working. If you find that you're using this Colab notebook extensively, and especially if you're using it to make work to display outside the classroom, **_please be sure to credit [Derrick Schultz](https://www.instagram.com/dvsmethid/?hl=en)_**, and I encourage you all to consider signing up for his [Patreon](https://www.patreon.com/bustbright) or [YouTube channel](https://www.youtube.com/channel/UCaZuPdmZ380SFUMKHVsv_AA/join). You can also send him a one-time payment on [Venmo](https://venmo.com/Derrick-Schultz). Derrick also has a Slack channel dedicated to this stuff, which you can access as a Patreon subscriber.
#
# ~ ~ ~ ~ ~ ~ ~ ~ ~
#
# This Notebook was last updated: March 30, 2021 by [Doug Rosman](https://dougrosman.com/).
#
# Additional Colab and Python help from Blake Fall-Conroy.
#
# ~ ~ ~ ~ ~ ~ ~ ~ ~

# %% [markdown]
# ## Connecting to a GPU instance
#
# Let’s start by checking to see what GPU we’ve been assigned. This will also connect the notebook to a GPU runtime, meaning you'll now officially start using your ~8 hours of free GPU time.
#
# Ideally the GPU we get is a V100, but a P100 is fine too. Other GPUs may lead to issues.

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-5256f904-909a-ad5f-c4f6-3a1bf2b0983e)

# %% [markdown]
# # Setup
# First, let’s connect our Google Drive account. This is optional but highly recommended. (You should definitely do this).
#
# After completing this step, I recommend opening another tab in your browser to your Google Drive folder. Even though you can access your Google Drive from this notebook, it's much easier to work with your files in the regular Google Drive interface.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install repo/Move into StyleGAN2-ADA-PyTorch repo if already installed
#
# The next cell will install the StyleGAN repository in Google Drive. If you have already installed it it will just move into that folder. If you don’t have Google Drive connected it will just install the necessary code in Colab.

# %%
import os
if os.path.isdir("/content/drive/MyDrive/colab-sg2-ada-pytorch"):
    # %cd "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/dougrosman/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/dougrosman/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../

# !pip install ninja opensimplex
# Out:
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch
# Collecting ninja
#   Downloading https://files.pythonhosted.org/packages/1d/de/393468f2a37fc2c1dc3a06afc37775e27fde2d16845424141d4da62c686d/ninja-1.10.0.post2-py3-none-manylinux1_x86_64.whl (107kB)
#      |████████████████████████████████| 112kB 5.3MB/s
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/9c/ad/9b758f9ff9dcd23fc574bb3aa1de844adb1179c9be9711e9f798614d4b2f/opensimplex-0.3-py3-none-any.whl
# Installing collected packages: ninja, opensimplex
# Successfully installed ninja-1.10.0.post2 opensimplex-0.3

# %% [markdown]
# ### **_Do not run this cell unless explicitly told to by Doug_**

# %%
# %cd "/content/drive/My Drive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
# !git config --global user.name "dougrosman"
# !git config --global user.email "drosman@saic.edu"
# !git fetch origin
# !git pull
# !git checkout origin/main -- train.py generate.py
# Out:
# /content/drive/My Drive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/dougrosman/stylegan2-ada-pytorch
#    3330aa3..beca8f2  main       -> origin/main
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %% [markdown]
# # Dataset Preparation - Uploading your data set
#
# Upload a .zip of square images to the `datasets` folder. Previously you had to convert your model to .tfrecords. That’s no longer needed :)
#
# This snippet uses an augmented version of the original dataset_tool.py from Nvidia's repo that can handle a wider variety of image types without failing.
#
# ### **Mac Users**
#
# The .zip folders you make on you Mac are likely to _fail_ if you use the standard method of compressing your folders (i.e. right-clicking on the folder and selecting _Compress "folder"_). Your Mac automatically creates a hidden folder in the .zip that becomes visible when you extract the .zip files on a non-Mac (like in this Colab, for instance). This causes problems.
#
# ![bad zip](https://raw.githubusercontent.com/dougrosman/stylegan2-ada-pytorch/main/images/bad_zip_apple.png)
#
# To solve this, download and install a third-party app called [Keka](https://www.keka.io/en/), and use that to create a .zip folder.
# #### **To compress a folder with Keka:**
# 1. Open Keka
# 2. Check the box next to '**Exclude Mac resource forks**'
# 3. Select '**ZIP**' from the top-right dropdown.
# 4. Drag and drop your folder directly onto Keka
# 5. It may ask you where to save your file. Select your destination and compress your folder. That .zip is safe to be uploaded to this Colab.
#
# ![good zip with Keka](https://raw.githubusercontent.com/dougrosman/stylegan2-ada-pytorch/main/images/keka.png)

# %% [markdown]
# # Batch cropping and resizing your images
#
# If your the images in your .zip folder are not uniformly square, run this cell to automatically resize and center crop your images to the specified resolution. Set the following arguments in the cell below (you'll need to scroll all the way to the right to change the width/height). After setting them, run the cell. This will take a couple minutes, depending on the quantity of images in your data set. **If this process fails for any reason, please let Doug know.**
#
# * __`--width="1024"`__ - set this to 1024 (or 512, or 256, depending on your needs)
# * __`--height="1024"`__ - set this to the same value as your --width
# * __`--source=/path/to/your/dataset.zip`__ (just change the dataset name at the end of the path to the name of the data set you want to process)
# * __`--dest=/path/to/your/dataset-processed.zip`__ (same as above, but add "-processed" to the end of the filename (e.g. mydata-processed.zip)

# %%
# !python dataset_tool-jpg.py --source=/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/banana.zip --dest=/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/banana-processed.zip --width=1024 --height=1024 --transform="center-crop"
# Out:
# 100% 98/98 [00:16<00:00,  5.79it/s]

# %% [markdown]
# ## Train model

# %% [markdown]
# Below are a series of variables you need to set to run the training. You probably won’t need to touch most of them.
#
# * `dataset_path`: this is the path to your .zip file (make sure that if you ran the data processing step above, you point to the processed data set.)
# * `resume_from`: if you’re starting a new dataset I recommend `'ffhq1024'` or `'./pretrained/wikiart.pkl'` (You can download other pretrained models [here](https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/). (for 512x512, you can use afhqcat.pkl, afhqdog.pkl,  afhqwild.pkl, or brecahad.pkl)
# * `mirror_x` and `mirror_y`: Allow the dataset to use horizontal or vertical mirroring.
# * `snapshot_count`: this determines how frequently your progress will be saved. If set to '1', a .pkl file will be saved with each tick (every ~30 mins or so). **I recommend this.** This will end up using a lot of space in your Google Drive, since you'll be saving a lot pickles, but if you have enough space, it's worth it. Setting this to '2' is also reasonable. This way, you are less likely to lose hours of training progress when Google shuts down your training.

# %%
#required: definitely edit these!
dataset_path = './datasets/keyboard_hands-1024.zip'
resume_from = './pretrained/wikiart.pkl' # a good pretrained model for 1024x1024 images
# resume_from = '/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00000-apple-processed-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000020.pkl'
aug_strength = 0
train_count = 0
mirror_x = True

#broken, don't use for now :(
#mirror_y = False

#optional: you might not need to edit these
gamma_value = 50.0
augs = 'bg'
config = '11gb-gpu'
snapshot_count = 1

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --resume=$resume_from --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count

# %% [markdown]
# ### Resume Training
#
# Once Colab has shutdown, you’ll need to resume your training. Reset the variables above, particularly the `resume_from` and `aug_strength` settings.
#
# 1. Point `resume_from` to the last .pkl you trained (you’ll find these in the `results` folder)
# 2. Update `aug_strength` to match the augment value of the last pkl file. Often you’ll see this in the console, but you may need to look at the `log.txt`. Updating this makes sure training stays as stable as possible.
# 3. You may want to update `train_count` to keep track of your training progress.
#
# Once all of this has been reset, run that variable cell and the training command cell after it.

# %% [markdown]
# ## Convert Legacy Model
#
# If you have an older version of a model (Tensorflow based StyleGAN, or Runway downloaded .pkl file) you’ll need to convert to the newest version. If you’ve trained in this notebook you do **not** need to use this cell.
#
# `--source`: path to model that you want to convert
#
# `--dest`: path and file name to convert to.

# %%
# !python legacy.py --source=/content/drive/MyDrive/runway.pkl --dest=/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/runway.pkl

# %% [markdown]
# ## Testing/Inference
#
# Also known as "Inference", "Evaluation" or "Testing" the model. This is the process of usinng your trained model to generate new material, usually images or videos.

# %% [markdown]
# ### Generate Single Images
#
# `--network`: Make sure the `--network` argument points to your .pkl file. (My preferred method is to right click on the file in the Files pane to your left and choose `Copy Path`, then paste that into the argument after the `=` sign).
#
# `--seeds`: This allows you to choose random seeds from the model. Remember that our input to StyleGAN is a 512-dimensional array. These seeds will generate those 512 values. Each seed will generate a different, random array. The same seed value will also always generate the same random array, so we can later use it for other purposes like interpolation.
#
# `--truncation`: Truncation, well, truncates the latent space. This can have a subtle or dramatic affect on your images depending on the value you use. The smaller the number the more realistic your images should appear, but this will also affect diversity. Most people choose between 0.5 and 1.0, but technically it's infinite.

# %%
# !python generate.py --outdir=./generated/kbhands138-random-0-49 --trunc=1.0 --seeds=0-49 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %% [markdown]
# ### Truncation Traversal
#
# Below you can take one seed and look at the changes to it across any truncation amount. -1 to 1 will be pretty realistic images, but the further out you get the weirder it gets.
#
# #### Options
# `--network`: Again, this should be the path to your .pkl file.
#
# `--seeds`: Pass this only one seed. Pick a favorite from your generated images.
#
# `--start`: Starting truncation value.
#
# `--stop`: Stopping truncation value. This should be larger than the start value. (Will probably break if its not).
#
# `--increment`: How much each frame should increment the truncation value. Make this really small if you want a long, slow interpolation. (stop-start/increment=total frames)

# %%
# !python generate.py --process="truncation" --outdir=./generated/kbhands138-trunc_21 --start=-2.5 --stop=2.5 --increment=0.01 --seeds=21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %%
# !python generate.py --process="truncation" --outdir=./generated/kbhands138-trunc_22 --start=-2.5 --stop=2.5 --increment=0.01 --seeds=22 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %%
# !python generate.py --process="truncation" --outdir=./generated/kbhands138-trunc_32 --start=-2.5 --stop=2.5 --increment=0.01 --seeds=32 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %%
# !python generate.py --process="truncation" --outdir=./generated/kbhands138-trunc_37 --start=-2.5 --stop=2.5 --increment=0.01 --seeds=37 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %%
# !python generate.py --process="truncation" --outdir=./generated/kbhands138-trunc_39 --start=-2.5 --stop=2.5 --increment=0.01 --seeds=39 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %% [markdown]
# ### Interpolations
#
# Interpolation is the process of generating very small changes to a vector in order to make it appear animated from frame to frame.
#
# We’ll look at different examples of interpolation below.
#
# #### Options
#
# `--network`: path to your .pkl file
#
# `--interpolation`: Walk type defines the type of interpolation you want. In some cases it can also specify whether you want the z space or the w space.
#
# `--frames`: How many frames you want to produce. Use this to manage the length of your video.
#
# `--trunc`: truncation value

# %% [markdown]
# #### Linear Interpolation

# %%
# !python generate.py --outdir=./generated/kbhands_lerp_z_21-39/ --space="z" --trunc=1 --process="interpolation" --seeds=21,22,32,37,39,21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/600 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/600 ...
# Generating image for frame 2/600 ...
# Generating image for frame 3/600 ...
# Generating image for frame 4/600 ...
# Generating image for frame 5/600 ...
# Generating image for frame 6/600 ...
# Generating image for frame 7/600 ...
# Generating image for frame 8/600 ...
# Generating image for frame 9/600 ...
# Generating image for frame 10/600 ...
# Generating image for frame 11/600 ...
# Generating image for frame 12/600 ...
# Generating image for frame 13/600 ...
# Generating image for frame 14/600 ...
# Generating image for frame 15/600 ...
# Generating image for frame 16/600 ...
# Generating image for frame 17/600 ...
# Generating image for frame 18/600 ...
# Generating image for frame 19/600 ...
# Generating image for frame 20/600 ...
# Generating image for frame 21/600 ...
# Generating image for frame 22/600 ...
# Generating image for frame 23/600 ...
# Generating image for frame 24/600 ...
# Generating image for frame 25/600 ...
# Generating image for frame 26/600 ...
# Generating image for frame 27/600 ...
# Generating image for frame 28/600 ...
# Generating image for frame 29/600 ...
# Generating image for frame 30/600 ...
# Generating image for frame 31/600 ...
# Generating image for frame 32/600 ...
# Generating image for frame 33/600 ...
# Generating image for frame 34/600 ...
# Generating image for frame 35/600 ...
# Generating image for frame 36/600 ...
# Generating image for frame 37/600 ...
# Generating image for frame 38/600 ...
# Generating image for frame 39/600 ...
# Generating image for frame 40/600 ...
# Generating image for frame 41/600 ...
# Generating image for frame 42/600 ...
# Generating image for frame 43/600 ...
# Generating image for frame 44/600 ...
# Generating image for frame 45/600 ...
# Generating image for frame 46/600 ...
# Generating image for frame 47/600 ...
# Generating image for frame 48/600 ...
# Generating image for frame 49/600 ...
# Generating image for frame 50/600 ...
# Generating image for frame 51/600 ...
# Generating image for frame 52/600 ...
# Generating image for frame 53/600 ...
# Generating image for frame 54/600 ...
# Generating image for frame 55/600 ...
# Generating image for frame 56/600 ...
# Generating image for frame 57/600 ...
# Generating image for frame 58/600 ...
# Generating image for frame 59/600 ...
# Generating image for frame 60/600 ...
# Generating image for frame 61/600 ...
# Generating image for frame 62/600 ...
# Generating image for frame 63/600 ...
# Generating image for frame 64/600 ...
# Generating image for frame 65/600 ...
# Generating image for frame 66/600 ...
# Generating image for frame 67/600 ...
# Generating image for frame 68/600 ...
# Generating image for frame 69/600 ...
# Generating image for frame 70/600 ...
# Generating image for frame 71/600 ...
# Generating image for frame 72/600 ...
# Generating image for frame 73/600 ...
# Generating image for frame 74/600 ...
# Generating image for frame 75/600 ...
# Generating image for frame 76/600 ...
# Generating image for frame 77/600 ...
# Generating image for frame 78/600 ...
# Generating image for frame 79/600 ...
# Generating image for frame 80/600 ...
# Generating image for frame 81/600 ...
# Generating image for frame 82/600 ...
# Generating image for frame 83/600 ...
# Generating image for frame 84/600 ...
# Generating image for frame 85/600 ...
# Generating image for frame 86/600 ...
# Generating image for frame 87/600 ...
# Generating image for frame 88/600 ...
# Generating image for frame 89/600 ...
# Generating image for frame 90/600 ...
# Generating image for frame 91/600 ...
# Generating image for frame 92/600 ...
# Generating image for frame 93/600 ...
# Generating image for frame 94/600 ...
# Generating image for frame 95/600 ...
# Generating image for frame 96/600 ...
# Generating image for frame 97/600 ...
# Generating image for frame 98/600 ...
# Generating image for frame 99/600 ...
# Generating image for frame 100/600 ...
# Generating image for frame 101/600 ...
# Generating image for frame 102/600 ...
# Generating image for frame 103/600 ...
# Generating image for frame 104/600 ...
# Generating image for frame 105/600 ...
# Generating image for frame 106/600 ...
# Generating image for frame 107/600 ...
# Generating image for frame 108/600 ...
# Generating image for frame 109/600 ...
# Generating image for frame 110/600 ...
# Generating image for frame 111/600 ...
# Generating image for frame 112/600 ...
# Generating image for frame 113/600 ...
# Generating image for frame 114/600 ...
# Generating image for frame 115/600 ...
# Generating image for frame 116/600 ...
# Generating image for frame 117/600 ...
# Generating image for frame 118/600 ...
# Generating image for frame 119/600 ...
# Generating image for frame 120/600 ...
# Generating image for frame 121/600 ...
# Generating image for frame 122/600 ...
# Generating image for frame 123/600 ...
# Generating image for frame 124/600 ...
# Generating image for frame 125/600 ...
# Generating image for frame 126/600 ...
# Generating image for frame 127/600 ...
# Generating image for frame 128/600 ...
# Generating image for frame 129/600 ...
# Generating image for frame 130/600 ...
# Generating image for frame 131/600 ...
# Generating image for frame 132/600 ...
# Generating image for frame 133/600 ...
# Generating image for frame 134/600 ...
# Generating image for frame 135/600 ...
# Generating image for frame 136/600 ...
# Generating image for frame 137/600 ...
# Generating image for frame 138/600 ...
# Generating image for frame 139/600 ...
# Generating image for frame 140/600 ...
# Generating image for frame 141/600 ...
# Generating image for frame 142/600 ...
# Generating image for frame 143/600 ...
# Generating image for frame 144/600 ...
# Generating image for frame 145/600 ...
# Generating image for frame 146/600 ...
# Generating image for frame 147/600 ...
# Generating image for frame 148/600 ...
# Generating image for frame 149/600 ...
# Generating image for frame 150/600 ...
# Generating image for frame 151/600 ...
# Generating image for frame 152/600 ...
# Generating image for frame 153/600 ...
# Generating image for frame 154/600 ...
# Generating image for frame 155/600 ...
# Generating image for frame 156/600 ...
# Generating image for frame 157/600 ...
# Generating image for frame 158/600 ...
# Generating image for frame 159/600 ...
# Generating image for frame 160/600 ...
# Generating image for frame 161/600 ...
# Generating image for frame 162/600 ...
# Generating image for frame 163/600 ...
# Generating image for frame 164/600 ...
# Generating image for frame 165/600 ...
# Generating image for frame 166/600 ...
# Generating image for frame 167/600 ...
# Generating image for frame 168/600 ...
# Generating image for frame 169/600 ...
# Generating image for frame 170/600 ...
# Generating image for frame 171/600 ...
# Generating image for frame 172/600 ...
# Generating image for frame 173/600 ...
# Generating image for frame 174/600 ...
# Generating image for frame 175/600 ...
# Generating image for frame 176/600 ...
# Generating image for frame 177/600 ...
# Generating image for frame 178/600 ...
# Generating image for frame 179/600 ...
# Generating image for frame 180/600 ...
# Generating image for frame 181/600 ...
# Generating image for frame 182/600 ...
# Generating image for frame 183/600 ...
# Generating image for frame 184/600 ...
# Generating image for frame 185/600 ...
# Generating image for frame 186/600 ...
# Generating image for frame 187/600 ...
# Generating image for frame 188/600 ...
# Generating image for frame 189/600 ...
# Generating image for frame 190/600 ...
# Generating image for frame 191/600 ...
# Generating image for frame 192/600 ...
# Generating image for frame 193/600 ...
# Generating image for frame 194/600 ...
# Generating image for frame 195/600 ...
# Generating image for frame 196/600 ...
# Generating image for frame 197/600 ...
# Generating image for frame 198/600 ...
# Generating image for frame 199/600 ...
# Generating image for frame 200/600 ...
# Generating image for frame 201/600 ...
# Generating image for frame 202/600 ...
# Generating image for frame 203/600 ...
# Generating image for frame 204/600 ...
# Generating image for frame 205/600 ...
# Generating image for frame 206/600 ...
# Generating image for frame 207/600 ...
# Generating image for frame 208/600 ...
# Generating image for frame 209/600 ...
# Generating image for frame 210/600 ...
# Generating image for frame 211/600 ...
# Generating image for frame 212/600 ...
# Generating image for frame 213/600 ...
# Generating image for frame 214/600 ...
# Generating image for frame 215/600 ...
# Generating image for frame 216/600 ...
# Generating image for frame 217/600 ...
# Generating image for frame 218/600 ...
# Generating image for frame 219/600 ...
# Generating image for frame 220/600 ...
# Generating image for frame 221/600 ...
# Generating image for frame 222/600 ...
# Generating image for frame 223/600 ...
# Generating image for frame 224/600 ...
# Generating image for frame 225/600 ...
# Generating image for frame 226/600 ...
# Generating image for frame 227/600 ...
# Generating image for frame 228/600 ...
# Generating image for frame 229/600 ...
# Generating image for frame 230/600 ...
# Generating image for frame 231/600 ...
# Generating image for frame 232/600 ...
# Generating image for frame 233/600 ...
# Generating image for frame 234/600 ...
# Generating image for frame 235/600 ...
# Generating image for frame 236/600 ...
# Generating image for frame 237/600 ...
# Generating image for frame 238/600 ...
# Generating image for frame 239/600 ...
# Generating image for frame 240/600 ...
# Generating image for frame 241/600 ...
# Generating image for frame 242/600 ...
# Generating image for frame 243/600 ...
# Generating image for frame 244/600 ...
# Generating image for frame 245/600 ...
# Generating image for frame 246/600 ...
# Generating image for frame 247/600 ...
# Generating image for frame 248/600 ...
# Generating image for frame 249/600 ...
# Generating image for frame 250/600 ...
# Generating image for frame 251/600 ...
# Generating image for frame 252/600 ...
# Generating image for frame 253/600 ...
# Generating image for frame 254/600 ...
# Generating image for frame 255/600 ...
# Generating image for frame 256/600 ...
# Generating image for frame 257/600 ...
# Generating image for frame 258/600 ...
# Generating image for frame 259/600 ...
# Generating image for frame 260/600 ...
# Generating image for frame 261/600 ...
# Generating image for frame 262/600 ...
# Generating image for frame 263/600 ...
# Generating image for frame 264/600 ...
# Generating image for frame 265/600 ...
# Generating image for frame 266/600 ...
# Generating image for frame 267/600 ...
# Generating image for frame 268/600 ...
# Generating image for frame 269/600 ...
# Generating image for frame 270/600 ...
# Generating image for frame 271/600 ...
# Generating image for frame 272/600 ...
# Generating image for frame 273/600 ...
# Generating image for frame 274/600 ...
# Generating image for frame 275/600 ...
# Generating image for frame 276/600 ...
# Generating image for frame 277/600 ...
# Generating image for frame 278/600 ...
# Generating image for frame 279/600 ...
# Generating image for frame 280/600 ...
# Generating image for frame 281/600 ...
# Generating image for frame 282/600 ...
# Generating image for frame 283/600 ...
# Generating image for frame 284/600 ...
# Generating image for frame 285/600 ...
# Generating image for frame 286/600 ...
# Generating image for frame 287/600 ...
# Generating image for frame 288/600 ...
# Generating image for frame 289/600 ...
# Generating image for frame 290/600 ...
# Generating image for frame 291/600 ...
# Generating image for frame 292/600 ...
# Generating image for frame 293/600 ...
# Generating image for frame 294/600 ...
# Generating image for frame 295/600 ...
# Generating image for frame 296/600 ...
# Generating image for frame 297/600 ...
# Generating image for frame 298/600 ...
# Generating image for frame 299/600 ...
# Generating image for frame 300/600 ...
# Generating image for frame 301/600 ...
# Generating image for frame 302/600 ...
# Generating image for frame 303/600 ...
# Generating image for frame 304/600 ...
# Generating image for frame 305/600 ...
# Generating image for frame 306/600 ...
# Generating image for frame 307/600 ...
# Generating image for frame 308/600 ...
# Generating image for frame 309/600 ...
# Generating image for frame 310/600 ...
# Generating image for frame 311/600 ...
# Generating image for frame 312/600 ...
# Generating image for frame 313/600 ...
# Generating image for frame 314/600 ...
# Generating image for frame 315/600 ...
# Generating image for frame 316/600 ...
# Generating image for frame 317/600 ...
# Generating image for frame 318/600 ...
# Generating image for frame 319/600 ...
# Generating image for frame 320/600 ...
# Generating image for frame 321/600 ...
# Generating image for frame 322/600 ...
# Generating image for frame 323/600 ...
# Generating image for frame 324/600 ...
# Generating image for frame 325/600 ...
# Generating image for frame 326/600 ...
# Generating image for frame 327/600 ...
# Generating image for frame 328/600 ...
# Generating image for frame 329/600 ...
# Generating image for frame 330/600 ...
# Generating image for frame 331/600 ...
# Generating image for frame 332/600 ...
# Generating image for frame 333/600 ...
# Generating image for frame 334/600 ...
# Generating image for frame 335/600 ...
# Generating image for frame 336/600 ...
# Generating image for frame 337/600 ...
# Generating image for frame 338/600 ...
# Generating image for frame 339/600 ...
# Generating image for frame 340/600 ...
# Generating image for frame 341/600 ...
# Generating image for frame 342/600 ...
# Generating image for frame 343/600 ...
# Generating image for frame 344/600 ...
# Generating image for frame 345/600 ...
# Generating image for frame 346/600 ...
# Generating image for frame 347/600 ...
# Generating image for frame 348/600 ...
# Generating image for frame 349/600 ...
# Generating image for frame 350/600 ...
# Generating image for frame 351/600 ...
# Generating image for frame 352/600 ...
# Generating image for frame 353/600 ...
# Generating image for frame 354/600 ...
# Generating image for frame 355/600 ...
# Generating image for frame 356/600 ...
# Generating image for frame 357/600 ...
# Generating image for frame 358/600 ...
# Generating image for frame 359/600 ...
# Generating image for frame 360/600 ...
# Generating image for frame 361/600 ...
# Generating image for frame 362/600 ...
# Generating image for frame 363/600 ...
# Generating image for frame 364/600 ...
# Generating image for frame 365/600 ...
# Generating image for frame 366/600 ...
# Generating image for frame 367/600 ...
# Generating image for frame 368/600 ...
# Generating image for frame 369/600 ...
# Generating image for frame 370/600 ...
# Generating image for frame 371/600 ...
# Generating image for frame 372/600 ...
# Generating image for frame 373/600 ...
# Generating image for frame 374/600 ...
# Generating image for frame 375/600 ...
# Generating image for frame 376/600 ...
# Generating image for frame 377/600 ...
# Generating image for frame 378/600 ...
# Generating image for frame 379/600 ...
# Generating image for frame 380/600 ...
# Generating image for frame 381/600 ...
# Generating image for frame 382/600 ...
# Generating image for frame 383/600 ...
# Generating image for frame 384/600 ...
# Generating image for frame 385/600 ...
# Generating image for frame 386/600 ...
# Generating image for frame 387/600 ...
# Generating image for frame 388/600 ...
# Generating image for frame 389/600 ...
# Generating image for frame 390/600 ...
# Generating image for frame 391/600 ...
# Generating image for frame 392/600 ...
# Generating image for frame 393/600 ...
# Generating image for frame 394/600 ...
# Generating image for frame 395/600 ...
# Generating image for frame 396/600 ...
# Generating image for frame 397/600 ...
# Generating image for frame 398/600 ...
# Generating image for frame 399/600 ...
# Generating image for frame 400/600 ...
# Generating image for frame 401/600 ...
# Generating image for frame 402/600 ...
# Generating image for frame 403/600 ...
# Generating image for frame 404/600 ...
# Generating image for frame 405/600 ...
# Generating image for frame 406/600 ...
# Generating image for frame 407/600 ...
# Generating image for frame 408/600 ...
# Generating image for frame 409/600 ...
# Generating image for frame 410/600 ...
# Generating image for frame 411/600 ...
# Generating image for frame 412/600 ...
# Generating image for frame 413/600 ...
# Generating image for frame 414/600 ...
# Generating image for frame 415/600 ...
# Generating image for frame 416/600 ...
# Generating image for frame 417/600 ...
# Generating image for frame 418/600 ...
# Generating image for frame 419/600 ...
# Generating image for frame 420/600 ...
# Generating image for frame 421/600 ...
# Generating image for frame 422/600 ...
# Generating image for frame 423/600 ...
# Generating image for frame 424/600 ...
# Generating image for frame 425/600 ...
# Generating image for frame 426/600 ...
# Generating image for frame 427/600 ...
# Generating image for frame 428/600 ...
# Generating image for frame 429/600 ...
# Generating image for frame 430/600 ...
# Generating image for frame 431/600 ...
# Generating image for frame 432/600 ...
# Generating image for frame 433/600 ...
# Generating image for frame 434/600 ...
# Generating image for frame 435/600 ...
# Generating image for frame 436/600 ...
# Generating image for frame 437/600 ...
# Generating image for frame 438/600 ...
# Generating image for frame 439/600 ...
# Generating image for frame 440/600 ...
# Generating image for frame 441/600 ...
# Generating image for frame 442/600 ...
# Generating image for frame 443/600 ...
# Generating image for frame 444/600 ...
# Generating image for frame 445/600 ...
# Generating image for frame 446/600 ...
# Generating image for frame 447/600 ...
# Generating image for frame 448/600 ...
# Generating image for frame 449/600 ...
# Generating image for frame 450/600 ...
# Generating image for frame 451/600 ...
# Generating image for frame 452/600 ...
# Generating image for frame 453/600 ...
# Generating image for frame 454/600 ...
# Generating image for frame 455/600 ...
# Generating image for frame 456/600 ...
# Generating image for frame 457/600 ...
# Generating image for frame 458/600 ...
# Generating image for frame 459/600 ...
# Generating image for frame 460/600 ...
# Generating image for frame 461/600 ...
# Generating image for frame 462/600 ...
# Generating image for frame 463/600 ...
# Generating image for frame 464/600 ...
# Generating image for frame 465/600 ...
# Generating image for frame 466/600 ...
# Generating image for frame 467/600 ...
# Generating image for frame 468/600 ...
# Generating image for frame 469/600 ...
# Generating image for frame 470/600 ...
# Generating image for frame 471/600 ...
# Generating image for frame 472/600 ...
# Generating image for frame 473/600 ...
# Generating image for frame 474/600 ...
# Generating image for frame 475/600 ...
# Generating image for frame 476/600 ...
# Generating image for frame 477/600 ...
# Generating image for frame 478/600 ...
# Generating image for frame 479/600 ...
# Generating image for frame 480/600 ...
# Generating image for frame 481/600 ...
# Generating image for frame 482/600 ...
# Generating image for frame 483/600 ...
# Generating image for frame 484/600 ...
# Generating image for frame 485/600 ...
# Generating image for frame 486/600 ...
# Generating image for frame 487/600 ...
# Generating image for frame 488/600 ...
# Generating image for frame 489/600 ...
# Generating image for frame 490/600 ...
# Generating image for frame 491/600 ...
# Generating image for frame 492/600 ...
# Generating image for frame 493/600 ...
# Generating image for frame 494/600 ...
# Generating image for frame 495/600 ...
# Generating image for frame 496/600 ...
# Generating image for frame 497/600 ...
# Generating image for frame 498/600 ...
# Generating image for frame 499/600 ...
# Generating image for frame 500/600 ...
# Generating image for frame 501/600 ...
# Generating image for frame 502/600 ...
# Generating image for frame 503/600 ...
# Generating image for frame 504/600 ...
# Generating image for frame 505/600 ...
# Generating image for frame 506/600 ...
# Generating image for frame 507/600 ...
# Generating image for frame 508/600 ...
# Generating image for frame 509/600 ...
# Generating image for frame 510/600 ...
# Generating image for frame 511/600 ...
# Generating image for frame 512/600 ...
# Generating image for frame 513/600 ...
# Generating image for frame 514/600 ...
# Generating image for frame 515/600 ...
# Generating image for frame 516/600 ...
# Generating image for frame 517/600 ...
# Generating image for frame 518/600 ...
# Generating image for frame 519/600 ...
# Generating image for frame 520/600 ...
# Generating image for frame 521/600 ...
# Generating image for frame 522/600 ...
# Generating image for frame 523/600 ...
# Generating image for frame 524/600 ...
# Generating image for frame 525/600 ...
# Generating image for frame 526/600 ...
# Generating image for frame 527/600 ...
# Generating image for frame 528/600 ...
# Generating image for frame 529/600 ...
# Generating image for frame 530/600 ...
# Generating image for frame 531/600 ...
# Generating image for frame 532/600 ...
# Generating image for frame 533/600 ...
# Generating image for frame 534/600 ...
# Generating image for frame 535/600 ...
# Generating image for frame 536/600 ...
# Generating image for frame 537/600 ...
# Generating image for frame 538/600 ...
# Generating image for frame 539/600 ...
# Generating image for frame 540/600 ...
# Generating image for frame 541/600 ...
# Generating image for frame 542/600 ...
# Generating image for frame 543/600 ...
# Generating image for frame 544/600 ...
# Generating image for frame 545/600 ...
# Generating image for frame 546/600 ...
# Generating image for frame 547/600 ...
# Generating image for frame 548/600 ...
# Generating image for frame 549/600 ...
# Generating image for frame 550/600 ...
# Generating image for frame 551/600 ...
# Generating image for frame 552/600 ...
# Generating image for frame 553/600 ...
# Generating image for frame 554/600 ...
# Generating image for frame 555/600 ...
# Generating image for frame 556/600 ...
# Generating image for frame 557/600 ...
# Generating image for frame 558/600 ...
# Generating image for frame 559/600 ...
# Generating image for frame 560/600 ...
# Generating image for frame 561/600 ...
# Generating image for frame 562/600 ...
# Generating image for frame 563/600 ...
# Generating image for frame 564/600 ...
# Generating image for frame 565/600 ...
# Generating image for frame 566/600 ...
# Generating image for frame 567/600 ...
# Generating image for frame 568/600 ...
# Generating image for frame 569/600 ...
# Generating image for frame 570/600 ...
# Generating image for frame 571/600 ...
# Generating image for frame 572/600 ...
# Generating image for frame 573/600 ...
# Generating image for frame 574/600 ...
# Generating image for frame 575/600 ...
# Generating image for frame 576/600 ...
# Generating image for frame 577/600 ...
# Generating image for frame 578/600 ...
# Generating image for frame 579/600 ...
# Generating image for frame 580/600 ...
# Generating image for frame 581/600 ...
# Generating image for frame 582/600 ...
# Generating image for frame 583/600 ...
# Generating image for frame 584/600 ...
# Generating image for frame 585/600 ...
# Generating image for frame 586/600 ...
# Generating image for frame 587/600 ...
# Generating image for frame 588/600 ...
# Generating image for frame 589/600 ...
# Generating image for frame 590/600 ...
# Generating image for frame 591/600 ...
# Generating image for frame 592/600 ...
# Generating image for frame 593/600 ...
# Generating image for frame 594/600 ...
# Generating image for frame 595/600 ...
# Generating image for frame 596/600 ...
# Generating image for frame 597/600 ...
# Generating image for frame 598/600 ...
# Generating image for frame 599/600 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_lerp_z_21-39/frames/frame%04d.png':
#   Duration: 00:00:24.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561ea10d9e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x561ea10d9e00] profile High, level 3.2
# [libx264 @ 0x561ea10d9e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_lerp_z_21-39//interpolation-linear-seeds_21_22_32_37_39_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  600 fps= 30 q=-1.0 Lsize=    3410kB time=00:00:19.90 bitrate=1403.8kbits/s speed=0.981x
# video:3403kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.210647%
# [libx264 @ 0x561ea10d9e00] frame I:3     Avg QP:19.32  size: 66153
# [libx264 @ 0x561ea10d9e00] frame P:222   Avg QP:22.19  size: 11824
# [libx264 @ 0x561ea10d9e00] frame B:375   Avg QP:26.18  size:  1761
# [libx264 @ 0x561ea10d9e00] consecutive B-frames: 13.8%  2.0% 19.5% 64.7%
# [libx264 @ 0x561ea10d9e00] mb I  I16..4:  9.1% 67.2% 23.7%
# [libx264 @ 0x561ea10d9e00] mb P  I16..4:  0.5%  2.4%  0.3%  P16..4: 34.9% 10.7%  6.2%  0.0%  0.0%    skip:44.9%
# [libx264 @ 0x561ea10d9e00] mb B  I16..4:  0.0%  0.3%  0.0%  B16..8: 22.8%  0.8%  0.2%  direct: 0.7%  skip:75.2%  L0:20.5% L1:75.3% BI: 4.2%
# [libx264 @ 0x561ea10d9e00] 8x8 transform intra:73.1% inter:74.2%
# [libx264 @ 0x561ea10d9e00] coded y,uvDC,uvAC intra: 72.7% 50.6% 7.9% inter: 9.1% 6.6% 0.0%
# [libx264 @ 0x561ea10d9e00] i16 v,h,dc,p:  7% 53%  2% 38%
# [libx264 @ 0x561ea10d9e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 24% 11%  6%  9%  8%  9% 10%  8%
# [libx264 @ 0x561ea10d9e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 29%  8%  5% 10%  8%  9%  6%  5%
# [libx264 @ 0x561ea10d9e00] i8c dc,h,v,p: 51% 25% 17%  6%
# [libx264 @ 0x561ea10d9e00] Weighted P-Frames: Y:1.8% UV:0.5%
# [libx264 @ 0x561ea10d9e00] ref P L0: 66.4% 21.1% 10.6%  1.9%  0.1%
# [libx264 @ 0x561ea10d9e00] ref B L0: 94.7%  4.4%  0.9%
# [libx264 @ 0x561ea10d9e00] ref B L1: 97.9%  2.1%
# [libx264 @ 0x561ea10d9e00] kb/s:1393.52

# %%
# !python generate.py --outdir=./generated/kbhands_lerp_w_21-39/ --space="w" --trunc=1 --process="interpolation" --seeds=21,22,32,37,39,21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Generating image for frame 0/600 ...
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/600 ...
# Generating image for frame 2/600 ...
# Generating image for frame 3/600 ...
# Generating image for frame 4/600 ...
# Generating image for frame 5/600 ...
# Generating image for frame 6/600 ...
# Generating image for frame 7/600 ...
# Generating image for frame 8/600 ...
# Generating image for frame 9/600 ...
# Generating image for frame 10/600 ...
# Generating image for frame 11/600 ...
# Generating image for frame 12/600 ...
# Generating image for frame 13/600 ...
# Generating image for frame 14/600 ...
# Generating image for frame 15/600 ...
# Generating image for frame 16/600 ...
# Generating image for frame 17/600 ...
# Generating image for frame 18/600 ...
# Generating image for frame 19/600 ...
# Generating image for frame 20/600 ...
# Generating image for frame 21/600 ...
# Generating image for frame 22/600 ...
# Generating image for frame 23/600 ...
# Generating image for frame 24/600 ...
# Generating image for frame 25/600 ...
# Generating image for frame 26/600 ...
# Generating image for frame 27/600 ...
# Generating image for frame 28/600 ...
# Generating image for frame 29/600 ...
# Generating image for frame 30/600 ...
# Generating image for frame 31/600 ...
# Generating image for frame 32/600 ...
# Generating image for frame 33/600 ...
# Generating image for frame 34/600 ...
# Generating image for frame 35/600 ...
# Generating image for frame 36/600 ...
# Generating image for frame 37/600 ...
# Generating image for frame 38/600 ...
# Generating image for frame 39/600 ...
# Generating image for frame 40/600 ...
# Generating image for frame 41/600 ...
# Generating image for frame 42/600 ...
# Generating image for frame 43/600 ...
# Generating image for frame 44/600 ...
# Generating image for frame 45/600 ...
# Generating image for frame 46/600 ...
# Generating image for frame 47/600 ...
# Generating image for frame 48/600 ...
# Generating image for frame 49/600 ...
# Generating image for frame 50/600 ...
# Generating image for frame 51/600 ...
# Generating image for frame 52/600 ...
# Generating image for frame 53/600 ...
# Generating image for frame 54/600 ...
# Generating image for frame 55/600 ...
# Generating image for frame 56/600 ...
# Generating image for frame 57/600 ...
# Generating image for frame 58/600 ...
# Generating image for frame 59/600 ...
# Generating image for frame 60/600 ...
# Generating image for frame 61/600 ...
# Generating image for frame 62/600 ...
# Generating image for frame 63/600 ...
# Generating image for frame 64/600 ...
# Generating image for frame 65/600 ...
# Generating image for frame 66/600 ...
# Generating image for frame 67/600 ...
# Generating image for frame 68/600 ...
# Generating image for frame 69/600 ...
# Generating image for frame 70/600 ...
# Generating image for frame 71/600 ...
# Generating image for frame 72/600 ...
# Generating image for frame 73/600 ...
# Generating image for frame 74/600 ...
# Generating image for frame 75/600 ...
# Generating image for frame 76/600 ...
# Generating image for frame 77/600 ...
# Generating image for frame 78/600 ...
# Generating image for frame 79/600 ...
# Generating image for frame 80/600 ...
# Generating image for frame 81/600 ...
# Generating image for frame 82/600 ...
# Generating image for frame 83/600 ...
# Generating image for frame 84/600 ...
# Generating image for frame 85/600 ...
# Generating image for frame 86/600 ...
# Generating image for frame 87/600 ...
# Generating image for frame 88/600 ...
# Generating image for frame 89/600 ...
# Generating image for frame 90/600 ...
# Generating image for frame 91/600 ...
# Generating image for frame 92/600 ...
# Generating image for frame 93/600 ...
# Generating image for frame 94/600 ...
# Generating image for frame 95/600 ...
# Generating image for frame 96/600 ...
# Generating image for frame 97/600 ...
# Generating image for frame 98/600 ...
# Generating image for frame 99/600 ...
# Generating image for frame 100/600 ...
# Generating image for frame 101/600 ...
# Generating image for frame 102/600 ...
# Generating image for frame 103/600 ...
# Generating image for frame 104/600 ...
# Generating image for frame 105/600 ...
# Generating image for frame 106/600 ...
# Generating image for frame 107/600 ...
# Generating image for frame 108/600 ...
# Generating image for frame 109/600 ...
# Generating image for frame 110/600 ...
# Generating image for frame 111/600 ...
# Generating image for frame 112/600 ...
# Generating image for frame 113/600 ...
# Generating image for frame 114/600 ...
# Generating image for frame 115/600 ...
# Generating image for frame 116/600 ...
# Generating image for frame 117/600 ...
# Generating image for frame 118/600 ...
# Generating image for frame 119/600 ...
# Generating image for frame 120/600 ...
# Generating image for frame 121/600 ...
# Generating image for frame 122/600 ...
# Generating image for frame 123/600 ...
# Generating image for frame 124/600 ...
# Generating image for frame 125/600 ...
# Generating image for frame 126/600 ...
# Generating image for frame 127/600 ...
# Generating image for frame 128/600 ...
# Generating image for frame 129/600 ...
# Generating image for frame 130/600 ...
# Generating image for frame 131/600 ...
# Generating image for frame 132/600 ...
# Generating image for frame 133/600 ...
# Generating image for frame 134/600 ...
# Generating image for frame 135/600 ...
# Generating image for frame 136/600 ...
# Generating image for frame 137/600 ...
# Generating image for frame 138/600 ...
# Generating image for frame 139/600 ...
# Generating image for frame 140/600 ...
# Generating image for frame 141/600 ...
# Generating image for frame 142/600 ...
# Generating image for frame 143/600 ...
# Generating image for frame 144/600 ...
# Generating image for frame 145/600 ...
# Generating image for frame 146/600 ...
# Generating image for frame 147/600 ...
# Generating image for frame 148/600 ...
# Generating image for frame 149/600 ...
# Generating image for frame 150/600 ...
# Generating image for frame 151/600 ...
# Generating image for frame 152/600 ...
# Generating image for frame 153/600 ...
# Generating image for frame 154/600 ...
# Generating image for frame 155/600 ...
# Generating image for frame 156/600 ...
# Generating image for frame 157/600 ...
# Generating image for frame 158/600 ...
# Generating image for frame 159/600 ...
# Generating image for frame 160/600 ...
# Generating image for frame 161/600 ...
# Generating image for frame 162/600 ...
# Generating image for frame 163/600 ...
# Generating image for frame 164/600 ...
# Generating image for frame 165/600 ...
# Generating image for frame 166/600 ...
# Generating image for frame 167/600 ...
# Generating image for frame 168/600 ...
# Generating image for frame 169/600 ...
# Generating image for frame 170/600 ...
# Generating image for frame 171/600 ...
# Generating image for frame 172/600 ...
# Generating image for frame 173/600 ...
# Generating image for frame 174/600 ...
# Generating image for frame 175/600 ...
# Generating image for frame 176/600 ...
# Generating image for frame 177/600 ...
# Generating image for frame 178/600 ...
# Generating image for frame 179/600 ...
# Generating image for frame 180/600 ...
# Generating image for frame 181/600 ...
# Generating image for frame 182/600 ...
# Generating image for frame 183/600 ...
# Generating image for frame 184/600 ...
# Generating image for frame 185/600 ...
# Generating image for frame 186/600 ...
# Generating image for frame 187/600 ...
# Generating image for frame 188/600 ...
# Generating image for frame 189/600 ...
# Generating image for frame 190/600 ...
# Generating image for frame 191/600 ...
# Generating image for frame 192/600 ...
# Generating image for frame 193/600 ...
# Generating image for frame 194/600 ...
# Generating image for frame 195/600 ...
# Generating image for frame 196/600 ...
# Generating image for frame 197/600 ...
# Generating image for frame 198/600 ...
# Generating image for frame 199/600 ...
# Generating image for frame 200/600 ...
# Generating image for frame 201/600 ...
# Generating image for frame 202/600 ...
# Generating image for frame 203/600 ...
# Generating image for frame 204/600 ...
# Generating image for frame 205/600 ...
# Generating image for frame 206/600 ...
# Generating image for frame 207/600 ...
# Generating image for frame 208/600 ...
# Generating image for frame 209/600 ...
# Generating image for frame 210/600 ...
# Generating image for frame 211/600 ...
# Generating image for frame 212/600 ...
# Generating image for frame 213/600 ...
# Generating image for frame 214/600 ...
# Generating image for frame 215/600 ...
# Generating image for frame 216/600 ...
# Generating image for frame 217/600 ...
# Generating image for frame 218/600 ...
# Generating image for frame 219/600 ...
# Generating image for frame 220/600 ...
# Generating image for frame 221/600 ...
# Generating image for frame 222/600 ...
# Generating image for frame 223/600 ...
# Generating image for frame 224/600 ...
# Generating image for frame 225/600 ...
# Generating image for frame 226/600 ...
# Generating image for frame 227/600 ...
# Generating image for frame 228/600 ...
# Generating image for frame 229/600 ...
# Generating image for frame 230/600 ...
# Generating image for frame 231/600 ...
# Generating image for frame 232/600 ...
# Generating image for frame 233/600 ...
# Generating image for frame 234/600 ...
# Generating image for frame 235/600 ...
# Generating image for frame 236/600 ...
# Generating image for frame 237/600 ...
# Generating image for frame 238/600 ...
# Generating image for frame 239/600 ...
# Generating image for frame 240/600 ...
# Generating image for frame 241/600 ...
# Generating image for frame 242/600 ...
# Generating image for frame 243/600 ...
# Generating image for frame 244/600 ...
# Generating image for frame 245/600 ...
# Generating image for frame 246/600 ...
# Generating image for frame 247/600 ...
# Generating image for frame 248/600 ...
# Generating image for frame 249/600 ...
# Generating image for frame 250/600 ...
# Generating image for frame 251/600 ...
# Generating image for frame 252/600 ...
# Generating image for frame 253/600 ...
# Generating image for frame 254/600 ...
# Generating image for frame 255/600 ...
# Generating image for frame 256/600 ...
# Generating image for frame 257/600 ...
# Generating image for frame 258/600 ...
# Generating image for frame 259/600 ...
# Generating image for frame 260/600 ...
# Generating image for frame 261/600 ...
# Generating image for frame 262/600 ...
# Generating image for frame 263/600 ...
# Generating image for frame 264/600 ...
# Generating image for frame 265/600 ...
# Generating image for frame 266/600 ...
# Generating image for frame 267/600 ...
# Generating image for frame 268/600 ...
# Generating image for frame 269/600 ...
# Generating image for frame 270/600 ...
# Generating image for frame 271/600 ...
# Generating image for frame 272/600 ...
# Generating image for frame 273/600 ...
# Generating image for frame 274/600 ...
# Generating image for frame 275/600 ...
# Generating image for frame 276/600 ...
# Generating image for frame 277/600 ...
# Generating image for frame 278/600 ...
# Generating image for frame 279/600 ...
# Generating image for frame 280/600 ...
# Generating image for frame 281/600 ...
# Generating image for frame 282/600 ...
# Generating image for frame 283/600 ...
# Generating image for frame 284/600 ...
# Generating image for frame 285/600 ...
# Generating image for frame 286/600 ...
# Generating image for frame 287/600 ...
# Generating image for frame 288/600 ...
# Generating image for frame 289/600 ...
# Generating image for frame 290/600 ...
# Generating image for frame 291/600 ...
# Generating image for frame 292/600 ...
# Generating image for frame 293/600 ...
# Generating image for frame 294/600 ...
# Generating image for frame 295/600 ...
# Generating image for frame 296/600 ...
# Generating image for frame 297/600 ...
# Generating image for frame 298/600 ...
# Generating image for frame 299/600 ...
# Generating image for frame 300/600 ...
# Generating image for frame 301/600 ...
# Generating image for frame 302/600 ...
# Generating image for frame 303/600 ...
# Generating image for frame 304/600 ...
# Generating image for frame 305/600 ...
# Generating image for frame 306/600 ...
# Generating image for frame 307/600 ...
# Generating image for frame 308/600 ...
# Generating image for frame 309/600 ...
# Generating image for frame 310/600 ...
# Generating image for frame 311/600 ...
# Generating image for frame 312/600 ...
# Generating image for frame 313/600 ...
# Generating image for frame 314/600 ...
# Generating image for frame 315/600 ...
# Generating image for frame 316/600 ...
# Generating image for frame 317/600 ...
# Generating image for frame 318/600 ...
# Generating image for frame 319/600 ...
# Generating image for frame 320/600 ...
# Generating image for frame 321/600 ...
# Generating image for frame 322/600 ...
# Generating image for frame 323/600 ...
# Generating image for frame 324/600 ...
# Generating image for frame 325/600 ...
# Generating image for frame 326/600 ...
# Generating image for frame 327/600 ...
# Generating image for frame 328/600 ...
# Generating image for frame 329/600 ...
# Generating image for frame 330/600 ...
# Generating image for frame 331/600 ...
# Generating image for frame 332/600 ...
# Generating image for frame 333/600 ...
# Generating image for frame 334/600 ...
# Generating image for frame 335/600 ...
# Generating image for frame 336/600 ...
# Generating image for frame 337/600 ...
# Generating image for frame 338/600 ...
# Generating image for frame 339/600 ...
# Generating image for frame 340/600 ...
# Generating image for frame 341/600 ...
# Generating image for frame 342/600 ...
# Generating image for frame 343/600 ...
# Generating image for frame 344/600 ...
# Generating image for frame 345/600 ...
# Generating image for frame 346/600 ...
# Generating image for frame 347/600 ...
# Generating image for frame 348/600 ...
# Generating image for frame 349/600 ...
# Generating image for frame 350/600 ...
# Generating image for frame 351/600 ...
# Generating image for frame 352/600 ...
# Generating image for frame 353/600 ...
# Generating image for frame 354/600 ...
# Generating image for frame 355/600 ...
# Generating image for frame 356/600 ...
# Generating image for frame 357/600 ...
# Generating image for frame 358/600 ...
# Generating image for frame 359/600 ...
# Generating image for frame 360/600 ...
# Generating image for frame 361/600 ...
# Generating image for frame 362/600 ...
# Generating image for frame 363/600 ...
# Generating image for frame 364/600 ...
# Generating image for frame 365/600 ...
# Generating image for frame 366/600 ...
# Generating image for frame 367/600 ...
# Generating image for frame 368/600 ...
# Generating image for frame 369/600 ...
# Generating image for frame 370/600 ...
# Generating image for frame 371/600 ...
# Generating image for frame 372/600 ...
# Generating image for frame 373/600 ...
# Generating image for frame 374/600 ...
# Generating image for frame 375/600 ...
# Generating image for frame 376/600 ...
# Generating image for frame 377/600 ...
# Generating image for frame 378/600 ...
# Generating image for frame 379/600 ...
# Generating image for frame 380/600 ...
# Generating image for frame 381/600 ...
# Generating image for frame 382/600 ...
# Generating image for frame 383/600 ...
# Generating image for frame 384/600 ...
# Generating image for frame 385/600 ...
# Generating image for frame 386/600 ...
# Generating image for frame 387/600 ...
# Generating image for frame 388/600 ...
# Generating image for frame 389/600 ...
# Generating image for frame 390/600 ...
# Generating image for frame 391/600 ...
# Generating image for frame 392/600 ...
# Generating image for frame 393/600 ...
# Generating image for frame 394/600 ...
# Generating image for frame 395/600 ...
# Generating image for frame 396/600 ...
# Generating image for frame 397/600 ...
# Generating image for frame 398/600 ...
# Generating image for frame 399/600 ...
# Generating image for frame 400/600 ...
# Generating image for frame 401/600 ...
# Generating image for frame 402/600 ...
# Generating image for frame 403/600 ...
# Generating image for frame 404/600 ...
# Generating image for frame 405/600 ...
# Generating image for frame 406/600 ...
# Generating image for frame 407/600 ...
# Generating image for frame 408/600 ...
# Generating image for frame 409/600 ...
# Generating image for frame 410/600 ...
# Generating image for frame 411/600 ...
# Generating image for frame 412/600 ...
# Generating image for frame 413/600 ...
# Generating image for frame 414/600 ...
# Generating image for frame 415/600 ...
# Generating image for frame 416/600 ...
# Generating image for frame 417/600 ...
# Generating image for frame 418/600 ...
# Generating image for frame 419/600 ...
# Generating image for frame 420/600 ...
# Generating image for frame 421/600 ...
# Generating image for frame 422/600 ...
# Generating image for frame 423/600 ...
# Generating image for frame 424/600 ...
# Generating image for frame 425/600 ...
# Generating image for frame 426/600 ...
# Generating image for frame 427/600 ...
# Generating image for frame 428/600 ...
# Generating image for frame 429/600 ...
# Generating image for frame 430/600 ...
# Generating image for frame 431/600 ...
# Generating image for frame 432/600 ...
# Generating image for frame 433/600 ...
# Generating image for frame 434/600 ...
# Generating image for frame 435/600 ...
# Generating image for frame 436/600 ...
# Generating image for frame 437/600 ...
# Generating image for frame 438/600 ...
# Generating image for frame 439/600 ...
# Generating image for frame 440/600 ...
# Generating image for frame 441/600 ...
# Generating image for frame 442/600 ...
# Generating image for frame 443/600 ...
# Generating image for frame 444/600 ...
# Generating image for frame 445/600 ...
# Generating image for frame 446/600 ...
# Generating image for frame 447/600 ...
# Generating image for frame 448/600 ...
# Generating image for frame 449/600 ...
# Generating image for frame 450/600 ...
# Generating image for frame 451/600 ...
# Generating image for frame 452/600 ...
# Generating image for frame 453/600 ...
# Generating image for frame 454/600 ...
# Generating image for frame 455/600 ...
# Generating image for frame 456/600 ...
# Generating image for frame 457/600 ...
# Generating image for frame 458/600 ...
# Generating image for frame 459/600 ...
# Generating image for frame 460/600 ...
# Generating image for frame 461/600 ...
# Generating image for frame 462/600 ...
# Generating image for frame 463/600 ...
# Generating image for frame 464/600 ...
# Generating image for frame 465/600 ...
# Generating image for frame 466/600 ...
# Generating image for frame 467/600 ...
# Generating image for frame 468/600 ...
# Generating image for frame 469/600 ...
# Generating image for frame 470/600 ...
# Generating image for frame 471/600 ...
# Generating image for frame 472/600 ...
# Generating image for frame 473/600 ...
# Generating image for frame 474/600 ...
# Generating image for frame 475/600 ...
# Generating image for frame 476/600 ...
# Generating image for frame 477/600 ...
# Generating image for frame 478/600 ...
# Generating image for frame 479/600 ...
# Generating image for frame 480/600 ...
# Generating image for frame 481/600 ...
# Generating image for frame 482/600 ...
# Generating image for frame 483/600 ...
# Generating image for frame 484/600 ...
# Generating image for frame 485/600 ...
# Generating image for frame 486/600 ...
# Generating image for frame 487/600 ...
# Generating image for frame 488/600 ...
# Generating image for frame 489/600 ...
# Generating image for frame 490/600 ...
# Generating image for frame 491/600 ...
# Generating image for frame 492/600 ...
# Generating image for frame 493/600 ...
# Generating image for frame 494/600 ...
# Generating image for frame 495/600 ...
# Generating image for frame 496/600 ...
# Generating image for frame 497/600 ...
# Generating image for frame 498/600 ...
# Generating image for frame 499/600 ...
# Generating image for frame 500/600 ...
# Generating image for frame 501/600 ...
# Generating image for frame 502/600 ...
# Generating image for frame 503/600 ...
# Generating image for frame 504/600 ...
# Generating image for frame 505/600 ...
# Generating image for frame 506/600 ...
# Generating image for frame 507/600 ...
# Generating image for frame 508/600 ...
# Generating image for frame 509/600 ...
# Generating image for frame 510/600 ...
# Generating image for frame 511/600 ...
# Generating image for frame 512/600 ...
# Generating image for frame 513/600 ...
# Generating image for frame 514/600 ...
# Generating image for frame 515/600 ...
# Generating image for frame 516/600 ...
# Generating image for frame 517/600 ...
# Generating image for frame 518/600 ...
# Generating image for frame 519/600 ...
# Generating image for frame 520/600 ...
# Generating image for frame 521/600 ...
# Generating image for frame 522/600 ...
# Generating image for frame 523/600 ...
# Generating image for frame 524/600 ...
# Generating image for frame 525/600 ...
# Generating image for frame 526/600 ...
# Generating image for frame 527/600 ...
# Generating image for frame 528/600 ...
# Generating image for frame 529/600 ...
# Generating image for frame 530/600 ...
# Generating image for frame 531/600 ...
# Generating image for frame 532/600 ...
# Generating image for frame 533/600 ...
# Generating image for frame 534/600 ...
# Generating image for frame 535/600 ...
# Generating image for frame 536/600 ...
# Generating image for frame 537/600 ...
# Generating image for frame 538/600 ...
# Generating image for frame 539/600 ...
# Generating image for frame 540/600 ...
# Generating image for frame 541/600 ...
# Generating image for frame 542/600 ...
# Generating image for frame 543/600 ...
# Generating image for frame 544/600 ...
# Generating image for frame 545/600 ...
# Generating image for frame 546/600 ...
# Generating image for frame 547/600 ...
# Generating image for frame 548/600 ...
# Generating image for frame 549/600 ...
# Generating image for frame 550/600 ...
# Generating image for frame 551/600 ...
# Generating image for frame 552/600 ...
# Generating image for frame 553/600 ...
# Generating image for frame 554/600 ...
# Generating image for frame 555/600 ...
# Generating image for frame 556/600 ...
# Generating image for frame 557/600 ...
# Generating image for frame 558/600 ...
# Generating image for frame 559/600 ...
# Generating image for frame 560/600 ...
# Generating image for frame 561/600 ...
# Generating image for frame 562/600 ...
# Generating image for frame 563/600 ...
# Generating image for frame 564/600 ...
# Generating image for frame 565/600 ...
# Generating image for frame 566/600 ...
# Generating image for frame 567/600 ...
# Generating image for frame 568/600 ...
# Generating image for frame 569/600 ...
# Generating image for frame 570/600 ...
# Generating image for frame 571/600 ...
# Generating image for frame 572/600 ...
# Generating image for frame 573/600 ...
# Generating image for frame 574/600 ...
# Generating image for frame 575/600 ...
# Generating image for frame 576/600 ...
# Generating image for frame 577/600 ...
# Generating image for frame 578/600 ...
# Generating image for frame 579/600 ...
# Generating image for frame 580/600 ...
# Generating image for frame 581/600 ...
# Generating image for frame 582/600 ...
# Generating image for frame 583/600 ...
# Generating image for frame 584/600 ...
# Generating image for frame 585/600 ...
# Generating image for frame 586/600 ...
# Generating image for frame 587/600 ...
# Generating image for frame 588/600 ...
# Generating image for frame 589/600 ...
# Generating image for frame 590/600 ...
# Generating image for frame 591/600 ...
# Generating image for frame 592/600 ...
# Generating image for frame 593/600 ...
# Generating image for frame 594/600 ...
# Generating image for frame 595/600 ...
# Generating image for frame 596/600 ...
# Generating image for frame 597/600 ...
# Generating image for frame 598/600 ...
# Generating image for frame 599/600 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_lerp_w_21-39/frames/frame%04d.png':
#   Duration: 00:00:24.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5583e22bbe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5583e22bbe00] profile High, level 3.2
# [libx264 @ 0x5583e22bbe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_lerp_w_21-39//interpolation-linear-seeds_21_22_32_37_39_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  600 fps= 31 q=-1.0 Lsize=    3204kB time=00:00:19.90 bitrate=1318.8kbits/s speed=1.04x
# video:3197kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.198770%
# [libx264 @ 0x5583e22bbe00] frame I:3     Avg QP:19.60  size: 65481
# [libx264 @ 0x5583e22bbe00] frame P:283   Avg QP:21.85  size:  9313
# [libx264 @ 0x5583e22bbe00] frame B:314   Avg QP:26.05  size:  1406
# [libx264 @ 0x5583e22bbe00] consecutive B-frames: 26.7%  1.0% 29.0% 43.3%
# [libx264 @ 0x5583e22bbe00] mb I  I16..4:  9.2% 67.7% 23.2%
# [libx264 @ 0x5583e22bbe00] mb P  I16..4:  0.3%  1.3%  0.2%  P16..4: 30.4%  8.7%  5.7%  0.0%  0.0%    skip:53.5%
# [libx264 @ 0x5583e22bbe00] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8: 21.7%  0.4%  0.1%  direct: 0.6%  skip:76.9%  L0:14.9% L1:81.0% BI: 4.1%
# [libx264 @ 0x5583e22bbe00] 8x8 transform intra:71.3% inter:73.9%
# [libx264 @ 0x5583e22bbe00] coded y,uvDC,uvAC intra: 73.3% 50.5% 8.9% inter: 8.8% 6.5% 0.0%
# [libx264 @ 0x5583e22bbe00] i16 v,h,dc,p:  6% 55%  2% 37%
# [libx264 @ 0x5583e22bbe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 27% 11%  6%  9%  7% 10%  9%  8%
# [libx264 @ 0x5583e22bbe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 30%  8%  5% 10%  8% 10%  6%  5%
# [libx264 @ 0x5583e22bbe00] i8c dc,h,v,p: 51% 28% 16%  6%
# [libx264 @ 0x5583e22bbe00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5583e22bbe00] ref P L0: 69.3% 20.6%  8.9%  1.3%
# [libx264 @ 0x5583e22bbe00] ref B L0: 95.5%  4.0%  0.5%
# [libx264 @ 0x5583e22bbe00] ref B L1: 98.6%  1.4%
# [libx264 @ 0x5583e22bbe00] kb/s:1309.38

# %%
# !zip -r vid1.zip /content/out/video1-w-0.5

# %% [markdown]
# #### Slerp Interpolation
#
# This gets a little heady, but technically linear interpolations are not the best in high-dimensional GANs. [This github link](https://github.com/soumith/dcgan.torch/issues/14) is one of the more popular explanations ad discussions.
#
# In reality I do not find a huge difference between linear and spherical interpolations (the difference in z- and w-space is enough in many cases), but I’ve implemented slerp here for anyone interested.
#
# Note: Slerp in w space currently isn’t supported. I’m working on it.

# %%
# !python generate.py --outdir=./generated/kbhands_slerp_21-39/ --interpolation="slerp" --trunc=1 --process="interpolation" --seeds=21,22,32,37,39,21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/600 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/600 ...
# Generating image for frame 2/600 ...
# Generating image for frame 3/600 ...
# Generating image for frame 4/600 ...
# Generating image for frame 5/600 ...
# Generating image for frame 6/600 ...
# Generating image for frame 7/600 ...
# Generating image for frame 8/600 ...
# Generating image for frame 9/600 ...
# Generating image for frame 10/600 ...
# Generating image for frame 11/600 ...
# Generating image for frame 12/600 ...
# Generating image for frame 13/600 ...
# Generating image for frame 14/600 ...
# Generating image for frame 15/600 ...
# Generating image for frame 16/600 ...
# Generating image for frame 17/600 ...
# Generating image for frame 18/600 ...
# Generating image for frame 19/600 ...
# Generating image for frame 20/600 ...
# Generating image for frame 21/600 ...
# Generating image for frame 22/600 ...
# Generating image for frame 23/600 ...
# Generating image for frame 24/600 ...
# Generating image for frame 25/600 ...
# Generating image for frame 26/600 ...
# Generating image for frame 27/600 ...
# Generating image for frame 28/600 ...
# Generating image for frame 29/600 ...
# Generating image for frame 30/600 ...
# Generating image for frame 31/600 ...
# Generating image for frame 32/600 ...
# Generating image for frame 33/600 ...
# Generating image for frame 34/600 ...
# Generating image for frame 35/600 ...
# Generating image for frame 36/600 ...
# Generating image for frame 37/600 ...
# Generating image for frame 38/600 ...
# Generating image for frame 39/600 ...
# Generating image for frame 40/600 ...
# Generating image for frame 41/600 ...
# Generating image for frame 42/600 ...
# Generating image for frame 43/600 ...
# Generating image for frame 44/600 ...
# Generating image for frame 45/600 ...
# Generating image for frame 46/600 ...
# Generating image for frame 47/600 ...
# Generating image for frame 48/600 ...
# Generating image for frame 49/600 ...
# Generating image for frame 50/600 ...
# Generating image for frame 51/600 ...
# Generating image for frame 52/600 ...
# Generating image for frame 53/600 ...
# Generating image for frame 54/600 ...
# Generating image for frame 55/600 ...
# Generating image for frame 56/600 ...
# Generating image for frame 57/600 ...
# Generating image for frame 58/600 ...
# Generating image for frame 59/600 ...
# Generating image for frame 60/600 ...
# Generating image for frame 61/600 ...
# Generating image for frame 62/600 ...
# Generating image for frame 63/600 ...
# Generating image for frame 64/600 ...
# Generating image for frame 65/600 ...
# Generating image for frame 66/600 ...
# Generating image for frame 67/600 ...
# Generating image for frame 68/600 ...
# Generating image for frame 69/600 ...
# Generating image for frame 70/600 ...
# Generating image for frame 71/600 ...
# Generating image for frame 72/600 ...
# Generating image for frame 73/600 ...
# Generating image for frame 74/600 ...
# Generating image for frame 75/600 ...
# Generating image for frame 76/600 ...
# Generating image for frame 77/600 ...
# Generating image for frame 78/600 ...
# Generating image for frame 79/600 ...
# Generating image for frame 80/600 ...
# Generating image for frame 81/600 ...
# Generating image for frame 82/600 ...
# Generating image for frame 83/600 ...
# Generating image for frame 84/600 ...
# Generating image for frame 85/600 ...
# Generating image for frame 86/600 ...
# Generating image for frame 87/600 ...
# Generating image for frame 88/600 ...
# Generating image for frame 89/600 ...
# Generating image for frame 90/600 ...
# Generating image for frame 91/600 ...
# Generating image for frame 92/600 ...
# Generating image for frame 93/600 ...
# Generating image for frame 94/600 ...
# Generating image for frame 95/600 ...
# Generating image for frame 96/600 ...
# Generating image for frame 97/600 ...
# Generating image for frame 98/600 ...
# Generating image for frame 99/600 ...
# Generating image for frame 100/600 ...
# Generating image for frame 101/600 ...
# Generating image for frame 102/600 ...
# Generating image for frame 103/600 ...
# Generating image for frame 104/600 ...
# Generating image for frame 105/600 ...
# Generating image for frame 106/600 ...
# Generating image for frame 107/600 ...
# Generating image for frame 108/600 ...
# Generating image for frame 109/600 ...
# Generating image for frame 110/600 ...
# Generating image for frame 111/600 ...
# Generating image for frame 112/600 ...
# Generating image for frame 113/600 ...
# Generating image for frame 114/600 ...
# Generating image for frame 115/600 ...
# Generating image for frame 116/600 ...
# Generating image for frame 117/600 ...
# Generating image for frame 118/600 ...
# Generating image for frame 119/600 ...
# Generating image for frame 120/600 ...
# Generating image for frame 121/600 ...
# Generating image for frame 122/600 ...
# Generating image for frame 123/600 ...
# Generating image for frame 124/600 ...
# Generating image for frame 125/600 ...
# Generating image for frame 126/600 ...
# Generating image for frame 127/600 ...
# Generating image for frame 128/600 ...
# Generating image for frame 129/600 ...
# Generating image for frame 130/600 ...
# Generating image for frame 131/600 ...
# Generating image for frame 132/600 ...
# Generating image for frame 133/600 ...
# Generating image for frame 134/600 ...
# Generating image for frame 135/600 ...
# Generating image for frame 136/600 ...
# Generating image for frame 137/600 ...
# Generating image for frame 138/600 ...
# Generating image for frame 139/600 ...
# Generating image for frame 140/600 ...
# Generating image for frame 141/600 ...
# Generating image for frame 142/600 ...
# Generating image for frame 143/600 ...
# Generating image for frame 144/600 ...
# Generating image for frame 145/600 ...
# Generating image for frame 146/600 ...
# Generating image for frame 147/600 ...
# Generating image for frame 148/600 ...
# Generating image for frame 149/600 ...
# Generating image for frame 150/600 ...
# Generating image for frame 151/600 ...
# Generating image for frame 152/600 ...
# Generating image for frame 153/600 ...
# Generating image for frame 154/600 ...
# Generating image for frame 155/600 ...
# Generating image for frame 156/600 ...
# Generating image for frame 157/600 ...
# Generating image for frame 158/600 ...
# Generating image for frame 159/600 ...
# Generating image for frame 160/600 ...
# Generating image for frame 161/600 ...
# Generating image for frame 162/600 ...
# Generating image for frame 163/600 ...
# Generating image for frame 164/600 ...
# Generating image for frame 165/600 ...
# Generating image for frame 166/600 ...
# Generating image for frame 167/600 ...
# Generating image for frame 168/600 ...
# Generating image for frame 169/600 ...
# Generating image for frame 170/600 ...
# Generating image for frame 171/600 ...
# Generating image for frame 172/600 ...
# Generating image for frame 173/600 ...
# Generating image for frame 174/600 ...
# Generating image for frame 175/600 ...
# Generating image for frame 176/600 ...
# Generating image for frame 177/600 ...
# Generating image for frame 178/600 ...
# Generating image for frame 179/600 ...
# Generating image for frame 180/600 ...
# Generating image for frame 181/600 ...
# Generating image for frame 182/600 ...
# Generating image for frame 183/600 ...
# Generating image for frame 184/600 ...
# Generating image for frame 185/600 ...
# Generating image for frame 186/600 ...
# Generating image for frame 187/600 ...
# Generating image for frame 188/600 ...
# Generating image for frame 189/600 ...
# Generating image for frame 190/600 ...
# Generating image for frame 191/600 ...
# Generating image for frame 192/600 ...
# Generating image for frame 193/600 ...
# Generating image for frame 194/600 ...
# Generating image for frame 195/600 ...
# Generating image for frame 196/600 ...
# Generating image for frame 197/600 ...
# Generating image for frame 198/600 ...
# Generating image for frame 199/600 ...
# Generating image for frame 200/600 ...
# Generating image for frame 201/600 ...
# Generating image for frame 202/600 ...
# Generating image for frame 203/600 ...
# Generating image for frame 204/600 ...
# Generating image for frame 205/600 ...
# Generating image for frame 206/600 ...
# Generating image for frame 207/600 ...
# Generating image for frame 208/600 ...
# Generating image for frame 209/600 ...
# Generating image for frame 210/600 ...
# Generating image for frame 211/600 ...
# Generating image for frame 212/600 ...
# Generating image for frame 213/600 ...
# Generating image for frame 214/600 ...
# Generating image for frame 215/600 ...
# Generating image for frame 216/600 ...
# Generating image for frame 217/600 ...
# Generating image for frame 218/600 ...
# Generating image for frame 219/600 ...
# Generating image for frame 220/600 ...
# Generating image for frame 221/600 ...
# Generating image for frame 222/600 ...
# Generating image for frame 223/600 ...
# Generating image for frame 224/600 ...
# Generating image for frame 225/600 ...
# Generating image for frame 226/600 ...
# Generating image for frame 227/600 ...
# Generating image for frame 228/600 ...
# Generating image for frame 229/600 ...
# Generating image for frame 230/600 ...
# Generating image for frame 231/600 ...
# Generating image for frame 232/600 ...
# Generating image for frame 233/600 ...
# Generating image for frame 234/600 ...
# Generating image for frame 235/600 ...
# Generating image for frame 236/600 ...
# Generating image for frame 237/600 ...
# Generating image for frame 238/600 ...
# Generating image for frame 239/600 ...
# Generating image for frame 240/600 ...
# Generating image for frame 241/600 ...
# Generating image for frame 242/600 ...
# Generating image for frame 243/600 ...
# Generating image for frame 244/600 ...
# Generating image for frame 245/600 ...
# Generating image for frame 246/600 ...
# Generating image for frame 247/600 ...
# Generating image for frame 248/600 ...
# Generating image for frame 249/600 ...
# Generating image for frame 250/600 ...
# Generating image for frame 251/600 ...
# Generating image for frame 252/600 ...
# Generating image for frame 253/600 ...
# Generating image for frame 254/600 ...
# Generating image for frame 255/600 ...
# Generating image for frame 256/600 ...
# Generating image for frame 257/600 ...
# Generating image for frame 258/600 ...
# Generating image for frame 259/600 ...
# Generating image for frame 260/600 ...
# Generating image for frame 261/600 ...
# Generating image for frame 262/600 ...
# Generating image for frame 263/600 ...
# Generating image for frame 264/600 ...
# Generating image for frame 265/600 ...
# Generating image for frame 266/600 ...
# Generating image for frame 267/600 ...
# Generating image for frame 268/600 ...
# Generating image for frame 269/600 ...
# Generating image for frame 270/600 ...
# Generating image for frame 271/600 ...
# Generating image for frame 272/600 ...
# Generating image for frame 273/600 ...
# Generating image for frame 274/600 ...
# Generating image for frame 275/600 ...
# Generating image for frame 276/600 ...
# Generating image for frame 277/600 ...
# Generating image for frame 278/600 ...
# Generating image for frame 279/600 ...
# Generating image for frame 280/600 ...
# Generating image for frame 281/600 ...
# Generating image for frame 282/600 ...
# Generating image for frame 283/600 ...
# Generating image for frame 284/600 ...
# Generating image for frame 285/600 ...
# Generating image for frame 286/600 ...
# Generating image for frame 287/600 ...
# Generating image for frame 288/600 ...
# Generating image for frame 289/600 ...
# Generating image for frame 290/600 ...
# Generating image for frame 291/600 ...
# Generating image for frame 292/600 ...
# Generating image for frame 293/600 ...
# Generating image for frame 294/600 ...
# Generating image for frame 295/600 ...
# Generating image for frame 296/600 ...
# Generating image for frame 297/600 ...
# Generating image for frame 298/600 ...
# Generating image for frame 299/600 ...
# Generating image for frame 300/600 ...
# Generating image for frame 301/600 ...
# Generating image for frame 302/600 ...
# Generating image for frame 303/600 ...
# Generating image for frame 304/600 ...
# Generating image for frame 305/600 ...
# Generating image for frame 306/600 ...
# Generating image for frame 307/600 ...
# Generating image for frame 308/600 ...
# Generating image for frame 309/600 ...
# Generating image for frame 310/600 ...
# Generating image for frame 311/600 ...
# Generating image for frame 312/600 ...
# Generating image for frame 313/600 ...
# Generating image for frame 314/600 ...
# Generating image for frame 315/600 ...
# Generating image for frame 316/600 ...
# Generating image for frame 317/600 ...
# Generating image for frame 318/600 ...
# Generating image for frame 319/600 ...
# Generating image for frame 320/600 ...
# Generating image for frame 321/600 ...
# Generating image for frame 322/600 ...
# Generating image for frame 323/600 ...
# Generating image for frame 324/600 ...
# Generating image for frame 325/600 ...
# Generating image for frame 326/600 ...
# Generating image for frame 327/600 ...
# Generating image for frame 328/600 ...
# Generating image for frame 329/600 ...
# Generating image for frame 330/600 ...
# Generating image for frame 331/600 ...
# Generating image for frame 332/600 ...
# Generating image for frame 333/600 ...
# Generating image for frame 334/600 ...
# Generating image for frame 335/600 ...
# Generating image for frame 336/600 ...
# Generating image for frame 337/600 ...
# Generating image for frame 338/600 ...
# Generating image for frame 339/600 ...
# Generating image for frame 340/600 ...
# Generating image for frame 341/600 ...
# Generating image for frame 342/600 ...
# Generating image for frame 343/600 ...
# Generating image for frame 344/600 ...
# Generating image for frame 345/600 ...
# Generating image for frame 346/600 ...
# Generating image for frame 347/600 ...
# Generating image for frame 348/600 ...
# Generating image for frame 349/600 ...
# Generating image for frame 350/600 ...
# Generating image for frame 351/600 ...
# Generating image for frame 352/600 ...
# Generating image for frame 353/600 ...
# Generating image for frame 354/600 ...
# Generating image for frame 355/600 ...
# Generating image for frame 356/600 ...
# Generating image for frame 357/600 ...
# Generating image for frame 358/600 ...
# Generating image for frame 359/600 ...
# Generating image for frame 360/600 ...
# Generating image for frame 361/600 ...
# Generating image for frame 362/600 ...
# Generating image for frame 363/600 ...
# Generating image for frame 364/600 ...
# Generating image for frame 365/600 ...
# Generating image for frame 366/600 ...
# Generating image for frame 367/600 ...
# Generating image for frame 368/600 ...
# Generating image for frame 369/600 ...
# Generating image for frame 370/600 ...
# Generating image for frame 371/600 ...
# Generating image for frame 372/600 ...
# Generating image for frame 373/600 ...
# Generating image for frame 374/600 ...
# Generating image for frame 375/600 ...
# Generating image for frame 376/600 ...
# Generating image for frame 377/600 ...
# Generating image for frame 378/600 ...
# Generating image for frame 379/600 ...
# Generating image for frame 380/600 ...
# Generating image for frame 381/600 ...
# Generating image for frame 382/600 ...
# Generating image for frame 383/600 ...
# Generating image for frame 384/600 ...
# Generating image for frame 385/600 ...
# Generating image for frame 386/600 ...
# Generating image for frame 387/600 ...
# Generating image for frame 388/600 ...
# Generating image for frame 389/600 ...
# Generating image for frame 390/600 ...
# Generating image for frame 391/600 ...
# Generating image for frame 392/600 ...
# Generating image for frame 393/600 ...
# Generating image for frame 394/600 ...
# Generating image for frame 395/600 ...
# Generating image for frame 396/600 ...
# Generating image for frame 397/600 ...
# Generating image for frame 398/600 ...
# Generating image for frame 399/600 ...
# Generating image for frame 400/600 ...
# Generating image for frame 401/600 ...
# Generating image for frame 402/600 ...
# Generating image for frame 403/600 ...
# Generating image for frame 404/600 ...
# Generating image for frame 405/600 ...
# Generating image for frame 406/600 ...
# Generating image for frame 407/600 ...
# Generating image for frame 408/600 ...
# Generating image for frame 409/600 ...
# Generating image for frame 410/600 ...
# Generating image for frame 411/600 ...
# Generating image for frame 412/600 ...
# Generating image for frame 413/600 ...
# Generating image for frame 414/600 ...
# Generating image for frame 415/600 ...
# Generating image for frame 416/600 ...
# Generating image for frame 417/600 ...
# Generating image for frame 418/600 ...
# Generating image for frame 419/600 ...
# Generating image for frame 420/600 ...
# Generating image for frame 421/600 ...
# Generating image for frame 422/600 ...
# Generating image for frame 423/600 ...
# Generating image for frame 424/600 ...
# Generating image for frame 425/600 ...
# Generating image for frame 426/600 ...
# Generating image for frame 427/600 ...
# Generating image for frame 428/600 ...
# Generating image for frame 429/600 ...
# Generating image for frame 430/600 ...
# Generating image for frame 431/600 ...
# Generating image for frame 432/600 ...
# Generating image for frame 433/600 ...
# Generating image for frame 434/600 ...
# Generating image for frame 435/600 ...
# Generating image for frame 436/600 ...
# Generating image for frame 437/600 ...
# Generating image for frame 438/600 ...
# Generating image for frame 439/600 ...
# Generating image for frame 440/600 ...
# Generating image for frame 441/600 ...
# Generating image for frame 442/600 ...
# Generating image for frame 443/600 ...
# Generating image for frame 444/600 ...
# Generating image for frame 445/600 ...
# Generating image for frame 446/600 ...
# Generating image for frame 447/600 ...
# Generating image for frame 448/600 ...
# Generating image for frame 449/600 ...
# Generating image for frame 450/600 ...
# Generating image for frame 451/600 ...
# Generating image for frame 452/600 ...
# Generating image for frame 453/600 ...
# Generating image for frame 454/600 ...
# Generating image for frame 455/600 ...
# Generating image for frame 456/600 ...
# Generating image for frame 457/600 ...
# Generating image for frame 458/600 ...
# Generating image for frame 459/600 ...
# Generating image for frame 460/600 ...
# Generating image for frame 461/600 ...
# Generating image for frame 462/600 ...
# Generating image for frame 463/600 ...
# Generating image for frame 464/600 ...
# Generating image for frame 465/600 ...
# Generating image for frame 466/600 ...
# Generating image for frame 467/600 ...
# Generating image for frame 468/600 ...
# Generating image for frame 469/600 ...
# Generating image for frame 470/600 ...
# Generating image for frame 471/600 ...
# Generating image for frame 472/600 ...
# Generating image for frame 473/600 ...
# Generating image for frame 474/600 ...
# Generating image for frame 475/600 ...
# Generating image for frame 476/600 ...
# Generating image for frame 477/600 ...
# Generating image for frame 478/600 ...
# Generating image for frame 479/600 ...
# Generating image for frame 480/600 ...
# Generating image for frame 481/600 ...
# Generating image for frame 482/600 ...
# Generating image for frame 483/600 ...
# Generating image for frame 484/600 ...
# Generating image for frame 485/600 ...
# Generating image for frame 486/600 ...
# Generating image for frame 487/600 ...
# Generating image for frame 488/600 ...
# Generating image for frame 489/600 ...
# Generating image for frame 490/600 ...
# Generating image for frame 491/600 ...
# Generating image for frame 492/600 ...
# Generating image for frame 493/600 ...
# Generating image for frame 494/600 ...
# Generating image for frame 495/600 ...
# Generating image for frame 496/600 ...
# Generating image for frame 497/600 ...
# Generating image for frame 498/600 ...
# Generating image for frame 499/600 ...
# Generating image for frame 500/600 ...
# Generating image for frame 501/600 ...
# Generating image for frame 502/600 ...
# Generating image for frame 503/600 ...
# Generating image for frame 504/600 ...
# Generating image for frame 505/600 ...
# Generating image for frame 506/600 ...
# Generating image for frame 507/600 ...
# Generating image for frame 508/600 ...
# Generating image for frame 509/600 ...
# Generating image for frame 510/600 ...
# Generating image for frame 511/600 ...
# Generating image for frame 512/600 ...
# Generating image for frame 513/600 ...
# Generating image for frame 514/600 ...
# Generating image for frame 515/600 ...
# Generating image for frame 516/600 ...
# Generating image for frame 517/600 ...
# Generating image for frame 518/600 ...
# Generating image for frame 519/600 ...
# Generating image for frame 520/600 ...
# Generating image for frame 521/600 ...
# Generating image for frame 522/600 ...
# Generating image for frame 523/600 ...
# Generating image for frame 524/600 ...
# Generating image for frame 525/600 ...
# Generating image for frame 526/600 ...
# Generating image for frame 527/600 ...
# Generating image for frame 528/600 ...
# Generating image for frame 529/600 ...
# Generating image for frame 530/600 ...
# Generating image for frame 531/600 ...
# Generating image for frame 532/600 ...
# Generating image for frame 533/600 ...
# Generating image for frame 534/600 ...
# Generating image for frame 535/600 ...
# Generating image for frame 536/600 ...
# Generating image for frame 537/600 ...
# Generating image for frame 538/600 ...
# Generating image for frame 539/600 ...
# Generating image for frame 540/600 ...
# Generating image for frame 541/600 ...
# Generating image for frame 542/600 ...
# Generating image for frame 543/600 ...
# Generating image for frame 544/600 ...
# Generating image for frame 545/600 ...
# Generating image for frame 546/600 ...
# Generating image for frame 547/600 ...
# Generating image for frame 548/600 ...
# Generating image for frame 549/600 ...
# Generating image for frame 550/600 ...
# Generating image for frame 551/600 ...
# Generating image for frame 552/600 ...
# Generating image for frame 553/600 ...
# Generating image for frame 554/600 ...
# Generating image for frame 555/600 ...
# Generating image for frame 556/600 ...
# Generating image for frame 557/600 ...
# Generating image for frame 558/600 ...
# Generating image for frame 559/600 ...
# Generating image for frame 560/600 ...
# Generating image for frame 561/600 ...
# Generating image for frame 562/600 ...
# Generating image for frame 563/600 ...
# Generating image for frame 564/600 ...
# Generating image for frame 565/600 ...
# Generating image for frame 566/600 ...
# Generating image for frame 567/600 ...
# Generating image for frame 568/600 ...
# Generating image for frame 569/600 ...
# Generating image for frame 570/600 ...
# Generating image for frame 571/600 ...
# Generating image for frame 572/600 ...
# Generating image for frame 573/600 ...
# Generating image for frame 574/600 ...
# Generating image for frame 575/600 ...
# Generating image for frame 576/600 ...
# Generating image for frame 577/600 ...
# Generating image for frame 578/600 ...
# Generating image for frame 579/600 ...
# Generating image for frame 580/600 ...
# Generating image for frame 581/600 ...
# Generating image for frame 582/600 ...
# Generating image for frame 583/600 ...
# Generating image for frame 584/600 ...
# Generating image for frame 585/600 ...
# Generating image for frame 586/600 ...
# Generating image for frame 587/600 ...
# Generating image for frame 588/600 ...
# Generating image for frame 589/600 ...
# Generating image for frame 590/600 ...
# Generating image for frame 591/600 ...
# Generating image for frame 592/600 ...
# Generating image for frame 593/600 ...
# Generating image for frame 594/600 ...
# Generating image for frame 595/600 ...
# Generating image for frame 596/600 ...
# Generating image for frame 597/600 ...
# Generating image for frame 598/600 ...
# Generating image for frame 599/600 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_slerp_21-39/frames/frame%04d.png':
#   Duration: 00:00:24.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5565800cbe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5565800cbe00] profile High, level 3.2
# [libx264 @ 0x5565800cbe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_slerp_21-39//interpolation-slerp-seeds_21_22_32_37_39_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  600 fps= 30 q=-1.0 Lsize=    3451kB time=00:00:19.90 bitrate=1420.8kbits/s speed=0.988x
# video:3444kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.204481%
# [libx264 @ 0x5565800cbe00] frame I:3     Avg QP:19.91  size: 62985
# [libx264 @ 0x5565800cbe00] frame P:227   Avg QP:22.19  size: 11830
# [libx264 @ 0x5565800cbe00] frame B:370   Avg QP:26.35  size:  1762
# [libx264 @ 0x5565800cbe00] consecutive B-frames: 13.8%  4.0% 23.5% 58.7%
# [libx264 @ 0x5565800cbe00] mb I  I16..4:  9.0% 67.6% 23.3%
# [libx264 @ 0x5565800cbe00] mb P  I16..4:  0.5%  2.4%  0.3%  P16..4: 35.1% 10.6%  6.3%  0.0%  0.0%    skip:44.8%
# [libx264 @ 0x5565800cbe00] mb B  I16..4:  0.0%  0.3%  0.0%  B16..8: 23.0%  0.8%  0.2%  direct: 0.7%  skip:75.0%  L0:19.9% L1:75.8% BI: 4.3%
# [libx264 @ 0x5565800cbe00] 8x8 transform intra:72.9% inter:74.2%
# [libx264 @ 0x5565800cbe00] coded y,uvDC,uvAC intra: 72.0% 51.0% 7.3% inter: 9.2% 6.7% 0.0%
# [libx264 @ 0x5565800cbe00] i16 v,h,dc,p:  8% 53%  2% 37%
# [libx264 @ 0x5565800cbe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 24% 11%  5%  9%  8% 10% 10%  8%
# [libx264 @ 0x5565800cbe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 28%  8%  5% 11%  8%  9%  6%  5%
# [libx264 @ 0x5565800cbe00] i8c dc,h,v,p: 51% 25% 17%  6%
# [libx264 @ 0x5565800cbe00] Weighted P-Frames: Y:0.4% UV:0.0%
# [libx264 @ 0x5565800cbe00] ref P L0: 66.9% 21.5% 10.0%  1.6%  0.0%
# [libx264 @ 0x5565800cbe00] ref B L0: 94.9%  4.4%  0.7%
# [libx264 @ 0x5565800cbe00] ref B L1: 98.3%  1.7%
# [libx264 @ 0x5565800cbe00] kb/s:1410.52

# %% [markdown]
# #### Noise Loop
#
# If you want to just make a random but fun interpolation of your model the noise loop is the way to go. It creates a random path thru the z space to show you a diverse set of images.
#
# `--interpolation="noiseloop"`: set this to use the noise loop funtion
#
# `--diameter`: This controls how "wide" the loop is. Make it smaller to show a less diverse range of samples. Make it larger to cover a lot of samples. This plus `--frames` can help determine how fast the video feels.
#
# `--random_seed`: this allows you to change your starting place in the z space. Note: this value has nothing to do with the seeds you use to generate images. It just allows you to randomize your start point (and if you want to return to it you can use the same seed multiple times).
#
# Noise loops currently only work in z space.

# %%
# !python generate.py --outdir=./generated/kbhands_noise_loop_21-d01/ --trunc=1 --process="interpolation" --interpolation="noiseloop" --diameter=0.01 --random_seed=21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30

# %%
# !python generate.py --outdir=./generated/kbhands_noise_loop_21-d25/ --trunc=1 --process="interpolation" --interpolation="noiseloop" --diameter=0.25 --random_seed=21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/120 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/120 ...
# Generating image for frame 2/120 ...
# Generating image for frame 3/120 ...
# Generating image for frame 4/120 ...
# Generating image for frame 5/120 ...
# Generating image for frame 6/120 ...
# Generating image for frame 7/120 ...
# Generating image for frame 8/120 ...
# Generating image for frame 9/120 ...
# Generating image for frame 10/120 ...
# Generating image for frame 11/120 ...
# Generating image for frame 12/120 ...
# Generating image for frame 13/120 ...
# Generating image for frame 14/120 ...
# Generating image for frame 15/120 ...
# Generating image for frame 16/120 ...
# Generating image for frame 17/120 ...
# Generating image for frame 18/120 ...
# Generating image for frame 19/120 ...
# Generating image for frame 20/120 ...
# Generating image for frame 21/120 ...
# Generating image for frame 22/120 ...
# Generating image for frame 23/120 ...
# Generating image for frame 24/120 ...
# Generating image for frame 25/120 ...
# Generating image for frame 26/120 ...
# Generating image for frame 27/120 ...
# Generating image for frame 28/120 ...
# Generating image for frame 29/120 ...
# Generating image for frame 30/120 ...
# Generating image for frame 31/120 ...
# Generating image for frame 32/120 ...
# Generating image for frame 33/120 ...
# Generating image for frame 34/120 ...
# Generating image for frame 35/120 ...
# Generating image for frame 36/120 ...
# Generating image for frame 37/120 ...
# Generating image for frame 38/120 ...
# Generating image for frame 39/120 ...
# Generating image for frame 40/120 ...
# Generating image for frame 41/120 ...
# Generating image for frame 42/120 ...
# Generating image for frame 43/120 ...
# Generating image for frame 44/120 ...
# Generating image for frame 45/120 ...
# Generating image for frame 46/120 ...
# Generating image for frame 47/120 ...
# Generating image for frame 48/120 ...
# Generating image for frame 49/120 ...
# Generating image for frame 50/120 ...
# Generating image for frame 51/120 ...
# Generating image for frame 52/120 ...
# Generating image for frame 53/120 ...
# Generating image for frame 54/120 ...
# Generating image for frame 55/120 ...
# Generating image for frame 56/120 ...
# Generating image for frame 57/120 ...
# Generating image for frame 58/120 ...
# Generating image for frame 59/120 ...
# Generating image for frame 60/120 ...
# Generating image for frame 61/120 ...
# Generating image for frame 62/120 ...
# Generating image for frame 63/120 ...
# Generating image for frame 64/120 ...
# Generating image for frame 65/120 ...
# Generating image for frame 66/120 ...
# Generating image for frame 67/120 ...
# Generating image for frame 68/120 ...
# Generating image for frame 69/120 ...
# Generating image for frame 70/120 ...
# Generating image for frame 71/120 ...
# Generating image for frame 72/120 ...
# Generating image for frame 73/120 ...
# Generating image for frame 74/120 ...
# Generating image for frame 75/120 ...
# Generating image for frame 76/120 ...
# Generating image for frame 77/120 ...
# Generating image for frame 78/120 ...
# Generating image for frame 79/120 ...
# Generating image for frame 80/120 ...
# Generating image for frame 81/120 ...
# Generating image for frame 82/120 ...
# Generating image for frame 83/120 ...
# Generating image for frame 84/120 ...
# Generating image for frame 85/120 ...
# Generating image for frame 86/120 ...
# Generating image for frame 87/120 ...
# Generating image for frame 88/120 ...
# Generating image for frame 89/120 ...
# Generating image for frame 90/120 ...
# Generating image for frame 91/120 ...
# Generating image for frame 92/120 ...
# Generating image for frame 93/120 ...
# Generating image for frame 94/120 ...
# Generating image for frame 95/120 ...
# Generating image for frame 96/120 ...
# Generating image for frame 97/120 ...
# Generating image for frame 98/120 ...
# Generating image for frame 99/120 ...
# Generating image for frame 100/120 ...
# Generating image for frame 101/120 ...
# Generating image for frame 102/120 ...
# Generating image for frame 103/120 ...
# Generating image for frame 104/120 ...
# Generating image for frame 105/120 ...
# Generating image for frame 106/120 ...
# Generating image for frame 107/120 ...
# Generating image for frame 108/120 ...
# Generating image for frame 109/120 ...
# Generating image for frame 110/120 ...
# Generating image for frame 111/120 ...
# Generating image for frame 112/120 ...
# Generating image for frame 113/120 ...
# Generating image for frame 114/120 ...
# Generating image for frame 115/120 ...
# Generating image for frame 116/120 ...
# Generating image for frame 117/120 ...
# Generating image for frame 118/120 ...
# Generating image for frame 119/120 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_noise_loop_21-d25/frames/frame%04d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56380335fe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56380335fe00] profile High, level 3.2
# [libx264 @ 0x56380335fe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_noise_loop_21-d25//interpolation-noiseloop-0.25dia-seed_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  120 fps= 29 q=-1.0 Lsize=     700kB time=00:00:03.90 bitrate=1471.3kbits/s speed=0.945x
# video:698kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.303732%
# [libx264 @ 0x56380335fe00] frame I:1     Avg QP:21.96  size: 50894
# [libx264 @ 0x56380335fe00] frame P:41    Avg QP:22.66  size: 11069
# [libx264 @ 0x56380335fe00] frame B:78    Avg QP:26.16  size:  2688
# [libx264 @ 0x56380335fe00] consecutive B-frames: 12.5%  0.0%  7.5% 80.0%
# [libx264 @ 0x56380335fe00] mb I  I16..4: 17.7% 61.8% 20.5%
# [libx264 @ 0x56380335fe00] mb P  I16..4:  2.2%  6.6%  0.5%  P16..4: 32.3%  8.0%  4.5%  0.0%  0.0%    skip:45.8%
# [libx264 @ 0x56380335fe00] mb B  I16..4:  0.3%  1.0%  0.1%  B16..8: 24.9%  1.4%  0.2%  direct: 1.3%  skip:70.9%  L0:29.6% L1:65.5% BI: 4.9%
# [libx264 @ 0x56380335fe00] 8x8 transform intra:70.2% inter:78.4%
# [libx264 @ 0x56380335fe00] coded y,uvDC,uvAC intra: 57.2% 46.3% 3.3% inter: 9.1% 7.8% 0.0%
# [libx264 @ 0x56380335fe00] i16 v,h,dc,p:  5% 56%  2% 37%
# [libx264 @ 0x56380335fe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 30% 14%  6%  7%  7%  7%  7%  8%
# [libx264 @ 0x56380335fe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 31%  9%  5%  9%  7%  7%  4%  4%
# [libx264 @ 0x56380335fe00] i8c dc,h,v,p: 51% 27% 16%  7%
# [libx264 @ 0x56380335fe00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56380335fe00] ref P L0: 64.9% 20.2% 10.8%  4.0%
# [libx264 @ 0x56380335fe00] ref B L0: 91.6%  5.4%  3.1%
# [libx264 @ 0x56380335fe00] ref B L1: 96.9%  3.1%
# [libx264 @ 0x56380335fe00] kb/s:1428.83

# %%
# !python generate.py --outdir=./generated/kbhands_noise_loop_21-d75/ --trunc=1 --process="interpolation" --interpolation="noiseloop" --diameter=0.75 --random_seed=21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/120 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/120 ...
# Generating image for frame 2/120 ...
# Generating image for frame 3/120 ...
# Generating image for frame 4/120 ...
# Generating image for frame 5/120 ...
# Generating image for frame 6/120 ...
# Generating image for frame 7/120 ...
# Generating image for frame 8/120 ...
# Generating image for frame 9/120 ...
# Generating image for frame 10/120 ...
# Generating image for frame 11/120 ...
# Generating image for frame 12/120 ...
# Generating image for frame 13/120 ...
# Generating image for frame 14/120 ...
# Generating image for frame 15/120 ...
# Generating image for frame 16/120 ...
# Generating image for frame 17/120 ...
# Generating image for frame 18/120 ...
# Generating image for frame 19/120 ...
# Generating image for frame 20/120 ...
# Generating image for frame 21/120 ...
# Generating image for frame 22/120 ...
# Generating image for frame 23/120 ...
# Generating image for frame 24/120 ...
# Generating image for frame 25/120 ...
# Generating image for frame 26/120 ...
# Generating image for frame 27/120 ...
# Generating image for frame 28/120 ...
# Generating image for frame 29/120 ...
# Generating image for frame 30/120 ...
# Generating image for frame 31/120 ...
# Generating image for frame 32/120 ...
# Generating image for frame 33/120 ...
# Generating image for frame 34/120 ...
# Generating image for frame 35/120 ...
# Generating image for frame 36/120 ...
# Generating image for frame 37/120 ...
# Generating image for frame 38/120 ...
# Generating image for frame 39/120 ...
# Generating image for frame 40/120 ...
# Generating image for frame 41/120 ...
# Generating image for frame 42/120 ...
# Generating image for frame 43/120 ...
# Generating image for frame 44/120 ...
# Generating image for frame 45/120 ...
# Generating image for frame 46/120 ...
# Generating image for frame 47/120 ...
# Generating image for frame 48/120 ...
# Generating image for frame 49/120 ...
# Generating image for frame 50/120 ...
# Generating image for frame 51/120 ...
# Generating image for frame 52/120 ...
# Generating image for frame 53/120 ...
# Generating image for frame 54/120 ...
# Generating image for frame 55/120 ...
# Generating image for frame 56/120 ...
# Generating image for frame 57/120 ...
# Generating image for frame 58/120 ...
# Generating image for frame 59/120 ...
# Generating image for frame 60/120 ...
# Generating image for frame 61/120 ...
# Generating image for frame 62/120 ...
# Generating image for frame 63/120 ...
# Generating image for frame 64/120 ...
# Generating image for frame 65/120 ...
# Generating image for frame 66/120 ...
# Generating image for frame 67/120 ...
# Generating image for frame 68/120 ...
# Generating image for frame 69/120 ...
# Generating image for frame 70/120 ...
# Generating image for frame 71/120 ...
# Generating image for frame 72/120 ...
# Generating image for frame 73/120 ...
# Generating image for frame 74/120 ...
# Generating image for frame 75/120 ...
# Generating image for frame 76/120 ...
# Generating image for frame 77/120 ...
# Generating image for frame 78/120 ...
# Generating image for frame 79/120 ...
# Generating image for frame 80/120 ...
# Generating image for frame 81/120 ...
# Generating image for frame 82/120 ...
# Generating image for frame 83/120 ...
# Generating image for frame 84/120 ...
# Generating image for frame 85/120 ...
# Generating image for frame 86/120 ...
# Generating image for frame 87/120 ...
# Generating image for frame 88/120 ...
# Generating image for frame 89/120 ...
# Generating image for frame 90/120 ...
# Generating image for frame 91/120 ...
# Generating image for frame 92/120 ...
# Generating image for frame 93/120 ...
# Generating image for frame 94/120 ...
# Generating image for frame 95/120 ...
# Generating image for frame 96/120 ...
# Generating image for frame 97/120 ...
# Generating image for frame 98/120 ...
# Generating image for frame 99/120 ...
# Generating image for frame 100/120 ...
# Generating image for frame 101/120 ...
# Generating image for frame 102/120 ...
# Generating image for frame 103/120 ...
# Generating image for frame 104/120 ...
# Generating image for frame 105/120 ...
# Generating image for frame 106/120 ...
# Generating image for frame 107/120 ...
# Generating image for frame 108/120 ...
# Generating image for frame 109/120 ...
# Generating image for frame 110/120 ...
# Generating image for frame 111/120 ...
# Generating image for frame 112/120 ...
# Generating image for frame 113/120 ...
# Generating image for frame 114/120 ...
# Generating image for frame 115/120 ...
# Generating image for frame 116/120 ...
# Generating image for frame 117/120 ...
# Generating image for frame 118/120 ...
# Generating image for frame 119/120 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_noise_loop_21-d75/frames/frame%04d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55beaa33de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55beaa33de00] profile High, level 3.2
# [libx264 @ 0x55beaa33de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_noise_loop_21-d75//interpolation-noiseloop-0.75dia-seed_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  120 fps= 27 q=-1.0 Lsize=     808kB time=00:00:03.90 bitrate=1696.5kbits/s speed=0.878x
# video:806kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.267202%
# [libx264 @ 0x55beaa33de00] frame I:1     Avg QP:23.04  size: 49860
# [libx264 @ 0x55beaa33de00] frame P:41    Avg QP:23.34  size: 13363
# [libx264 @ 0x55beaa33de00] frame B:78    Avg QP:26.56  size:  2903
# [libx264 @ 0x55beaa33de00] consecutive B-frames:  9.2%  8.3% 12.5% 70.0%
# [libx264 @ 0x55beaa33de00] mb I  I16..4: 11.6% 68.5% 19.9%
# [libx264 @ 0x55beaa33de00] mb P  I16..4:  2.2%  6.7%  0.7%  P16..4: 38.6% 10.5%  5.6%  0.0%  0.0%    skip:35.7%
# [libx264 @ 0x55beaa33de00] mb B  I16..4:  0.3%  0.9%  0.0%  B16..8: 27.7%  1.7%  0.3%  direct: 1.2%  skip:67.9%  L0:30.3% L1:65.1% BI: 4.6%
# [libx264 @ 0x55beaa33de00] 8x8 transform intra:70.0% inter:78.2%
# [libx264 @ 0x55beaa33de00] coded y,uvDC,uvAC intra: 59.0% 45.1% 4.9% inter: 11.0% 8.5% 0.0%
# [libx264 @ 0x55beaa33de00] i16 v,h,dc,p:  6% 61%  2% 31%
# [libx264 @ 0x55beaa33de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 30% 12%  5%  7%  7%  7%  7%  8%
# [libx264 @ 0x55beaa33de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 28%  9%  5% 10%  8%  7%  5%  4%
# [libx264 @ 0x55beaa33de00] i8c dc,h,v,p: 52% 27% 15%  6%
# [libx264 @ 0x55beaa33de00] Weighted P-Frames: Y:7.3% UV:2.4%
# [libx264 @ 0x55beaa33de00] ref P L0: 59.7% 24.3% 12.0%  3.9%  0.2%
# [libx264 @ 0x55beaa33de00] ref B L0: 92.0%  6.4%  1.6%
# [libx264 @ 0x55beaa33de00] ref B L1: 97.9%  2.1%
# [libx264 @ 0x55beaa33de00] kb/s:1648.31

# %%
# !python generate.py --outdir=./generated/kbhands_noise_loop_21-d125/ --trunc=1 --process="interpolation" --interpolation="noiseloop" --diameter=1.25 --random_seed=21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/120 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/120 ...
# Generating image for frame 2/120 ...
# Generating image for frame 3/120 ...
# Generating image for frame 4/120 ...
# Generating image for frame 5/120 ...
# Generating image for frame 6/120 ...
# Generating image for frame 7/120 ...
# Generating image for frame 8/120 ...
# Generating image for frame 9/120 ...
# Generating image for frame 10/120 ...
# Generating image for frame 11/120 ...
# Generating image for frame 12/120 ...
# Generating image for frame 13/120 ...
# Generating image for frame 14/120 ...
# Generating image for frame 15/120 ...
# Generating image for frame 16/120 ...
# Generating image for frame 17/120 ...
# Generating image for frame 18/120 ...
# Generating image for frame 19/120 ...
# Generating image for frame 20/120 ...
# Generating image for frame 21/120 ...
# Generating image for frame 22/120 ...
# Generating image for frame 23/120 ...
# Generating image for frame 24/120 ...
# Generating image for frame 25/120 ...
# Generating image for frame 26/120 ...
# Generating image for frame 27/120 ...
# Generating image for frame 28/120 ...
# Generating image for frame 29/120 ...
# Generating image for frame 30/120 ...
# Generating image for frame 31/120 ...
# Generating image for frame 32/120 ...
# Generating image for frame 33/120 ...
# Generating image for frame 34/120 ...
# Generating image for frame 35/120 ...
# Generating image for frame 36/120 ...
# Generating image for frame 37/120 ...
# Generating image for frame 38/120 ...
# Generating image for frame 39/120 ...
# Generating image for frame 40/120 ...
# Generating image for frame 41/120 ...
# Generating image for frame 42/120 ...
# Generating image for frame 43/120 ...
# Generating image for frame 44/120 ...
# Generating image for frame 45/120 ...
# Generating image for frame 46/120 ...
# Generating image for frame 47/120 ...
# Generating image for frame 48/120 ...
# Generating image for frame 49/120 ...
# Generating image for frame 50/120 ...
# Generating image for frame 51/120 ...
# Generating image for frame 52/120 ...
# Generating image for frame 53/120 ...
# Generating image for frame 54/120 ...
# Generating image for frame 55/120 ...
# Generating image for frame 56/120 ...
# Generating image for frame 57/120 ...
# Generating image for frame 58/120 ...
# Generating image for frame 59/120 ...
# Generating image for frame 60/120 ...
# Generating image for frame 61/120 ...
# Generating image for frame 62/120 ...
# Generating image for frame 63/120 ...
# Generating image for frame 64/120 ...
# Generating image for frame 65/120 ...
# Generating image for frame 66/120 ...
# Generating image for frame 67/120 ...
# Generating image for frame 68/120 ...
# Generating image for frame 69/120 ...
# Generating image for frame 70/120 ...
# Generating image for frame 71/120 ...
# Generating image for frame 72/120 ...
# Generating image for frame 73/120 ...
# Generating image for frame 74/120 ...
# Generating image for frame 75/120 ...
# Generating image for frame 76/120 ...
# Generating image for frame 77/120 ...
# Generating image for frame 78/120 ...
# Generating image for frame 79/120 ...
# Generating image for frame 80/120 ...
# Generating image for frame 81/120 ...
# Generating image for frame 82/120 ...
# Generating image for frame 83/120 ...
# Generating image for frame 84/120 ...
# Generating image for frame 85/120 ...
# Generating image for frame 86/120 ...
# Generating image for frame 87/120 ...
# Generating image for frame 88/120 ...
# Generating image for frame 89/120 ...
# Generating image for frame 90/120 ...
# Generating image for frame 91/120 ...
# Generating image for frame 92/120 ...
# Generating image for frame 93/120 ...
# Generating image for frame 94/120 ...
# Generating image for frame 95/120 ...
# Generating image for frame 96/120 ...
# Generating image for frame 97/120 ...
# Generating image for frame 98/120 ...
# Generating image for frame 99/120 ...
# Generating image for frame 100/120 ...
# Generating image for frame 101/120 ...
# Generating image for frame 102/120 ...
# Generating image for frame 103/120 ...
# Generating image for frame 104/120 ...
# Generating image for frame 105/120 ...
# Generating image for frame 106/120 ...
# Generating image for frame 107/120 ...
# Generating image for frame 108/120 ...
# Generating image for frame 109/120 ...
# Generating image for frame 110/120 ...
# Generating image for frame 111/120 ...
# Generating image for frame 112/120 ...
# Generating image for frame 113/120 ...
# Generating image for frame 114/120 ...
# Generating image for frame 115/120 ...
# Generating image for frame 116/120 ...
# Generating image for frame 117/120 ...
# Generating image for frame 118/120 ...
# Generating image for frame 119/120 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_noise_loop_21-d125/frames/frame%04d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c6d12e5e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c6d12e5e00] profile High, level 3.2
# [libx264 @ 0x55c6d12e5e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_noise_loop_21-d125//interpolation-noiseloop-1.25dia-seed_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  120 fps= 23 q=-1.0 Lsize=    1088kB time=00:00:03.90 bitrate=2284.9kbits/s speed=0.761x
# video:1086kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.200415%
# [libx264 @ 0x55c6d12e5e00] frame I:1     Avg QP:23.73  size: 47019
# [libx264 @ 0x55c6d12e5e00] frame P:38    Avg QP:24.28  size: 17602
# [libx264 @ 0x55c6d12e5e00] frame B:81    Avg QP:27.12  size:  4878
# [libx264 @ 0x55c6d12e5e00] consecutive B-frames: 10.0%  0.0%  0.0% 90.0%
# [libx264 @ 0x55c6d12e5e00] mb I  I16..4: 12.1% 66.7% 21.2%
# [libx264 @ 0x55c6d12e5e00] mb P  I16..4:  3.4% 10.5%  1.3%  P16..4: 41.0% 12.4%  5.8%  0.0%  0.0%    skip:25.5%
# [libx264 @ 0x55c6d12e5e00] mb B  I16..4:  0.4%  1.3%  0.1%  B16..8: 31.6%  3.7%  0.6%  direct: 2.1%  skip:60.2%  L0:38.9% L1:54.0% BI: 7.0%
# [libx264 @ 0x55c6d12e5e00] 8x8 transform intra:69.2% inter:79.3%
# [libx264 @ 0x55c6d12e5e00] coded y,uvDC,uvAC intra: 59.9% 42.2% 4.2% inter: 14.6% 10.2% 0.0%
# [libx264 @ 0x55c6d12e5e00] i16 v,h,dc,p:  6% 63%  2% 30%
# [libx264 @ 0x55c6d12e5e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 28% 12%  6%  8%  7%  7%  9%  8%
# [libx264 @ 0x55c6d12e5e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 28% 10%  5%  9%  8%  6%  6%  4%
# [libx264 @ 0x55c6d12e5e00] i8c dc,h,v,p: 54% 26% 15%  5%
# [libx264 @ 0x55c6d12e5e00] Weighted P-Frames: Y:26.3% UV:7.9%
# [libx264 @ 0x55c6d12e5e00] ref P L0: 49.1% 27.9% 14.8%  6.4%  1.9%
# [libx264 @ 0x55c6d12e5e00] ref B L0: 89.1%  7.9%  3.0%
# [libx264 @ 0x55c6d12e5e00] ref B L1: 97.1%  2.9%
# [libx264 @ 0x55c6d12e5e00] kb/s:2222.01

# %%
# !python generate.py --outdir=./generated/kbhands_noise_loop_21-d175/ --trunc=1 --process="interpolation" --interpolation="noiseloop" --diameter=1.75 --random_seed=21 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl --frames=120 --fps=30
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/120 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/120 ...
# Generating image for frame 2/120 ...
# Generating image for frame 3/120 ...
# Generating image for frame 4/120 ...
# Generating image for frame 5/120 ...
# Generating image for frame 6/120 ...
# Generating image for frame 7/120 ...
# Generating image for frame 8/120 ...
# Generating image for frame 9/120 ...
# Generating image for frame 10/120 ...
# Generating image for frame 11/120 ...
# Generating image for frame 12/120 ...
# Generating image for frame 13/120 ...
# Generating image for frame 14/120 ...
# Generating image for frame 15/120 ...
# Generating image for frame 16/120 ...
# Generating image for frame 17/120 ...
# Generating image for frame 18/120 ...
# Generating image for frame 19/120 ...
# Generating image for frame 20/120 ...
# Generating image for frame 21/120 ...
# Generating image for frame 22/120 ...
# Generating image for frame 23/120 ...
# Generating image for frame 24/120 ...
# Generating image for frame 25/120 ...
# Generating image for frame 26/120 ...
# Generating image for frame 27/120 ...
# Generating image for frame 28/120 ...
# Generating image for frame 29/120 ...
# Generating image for frame 30/120 ...
# Generating image for frame 31/120 ...
# Generating image for frame 32/120 ...
# Generating image for frame 33/120 ...
# Generating image for frame 34/120 ...
# Generating image for frame 35/120 ...
# Generating image for frame 36/120 ...
# Generating image for frame 37/120 ...
# Generating image for frame 38/120 ...
# Generating image for frame 39/120 ...
# Generating image for frame 40/120 ...
# Generating image for frame 41/120 ...
# Generating image for frame 42/120 ...
# Generating image for frame 43/120 ...
# Generating image for frame 44/120 ...
# Generating image for frame 45/120 ...
# Generating image for frame 46/120 ...
# Generating image for frame 47/120 ...
# Generating image for frame 48/120 ...
# Generating image for frame 49/120 ...
# Generating image for frame 50/120 ...
# Generating image for frame 51/120 ...
# Generating image for frame 52/120 ...
# Generating image for frame 53/120 ...
# Generating image for frame 54/120 ...
# Generating image for frame 55/120 ...
# Generating image for frame 56/120 ...
# Generating image for frame 57/120 ...
# Generating image for frame 58/120 ...
# Generating image for frame 59/120 ...
# Generating image for frame 60/120 ...
# Generating image for frame 61/120 ...
# Generating image for frame 62/120 ...
# Generating image for frame 63/120 ...
# Generating image for frame 64/120 ...
# Generating image for frame 65/120 ...
# Generating image for frame 66/120 ...
# Generating image for frame 67/120 ...
# Generating image for frame 68/120 ...
# Generating image for frame 69/120 ...
# Generating image for frame 70/120 ...
# Generating image for frame 71/120 ...
# Generating image for frame 72/120 ...
# Generating image for frame 73/120 ...
# Generating image for frame 74/120 ...
# Generating image for frame 75/120 ...
# Generating image for frame 76/120 ...
# Generating image for frame 77/120 ...
# Generating image for frame 78/120 ...
# Generating image for frame 79/120 ...
# Generating image for frame 80/120 ...
# Generating image for frame 81/120 ...
# Generating image for frame 82/120 ...
# Generating image for frame 83/120 ...
# Generating image for frame 84/120 ...
# Generating image for frame 85/120 ...
# Generating image for frame 86/120 ...
# Generating image for frame 87/120 ...
# Generating image for frame 88/120 ...
# Generating image for frame 89/120 ...
# Generating image for frame 90/120 ...
# Generating image for frame 91/120 ...
# Generating image for frame 92/120 ...
# Generating image for frame 93/120 ...
# Generating image for frame 94/120 ...
# Generating image for frame 95/120 ...
# Generating image for frame 96/120 ...
# Generating image for frame 97/120 ...
# Generating image for frame 98/120 ...
# Generating image for frame 99/120 ...
# Generating image for frame 100/120 ...
# Generating image for frame 101/120 ...
# Generating image for frame 102/120 ...
# Generating image for frame 103/120 ...
# Generating image for frame 104/120 ...
# Generating image for frame 105/120 ...
# Generating image for frame 106/120 ...
# Generating image for frame 107/120 ...
# Generating image for frame 108/120 ...
# Generating image for frame 109/120 ...
# Generating image for frame 110/120 ...
# Generating image for frame 111/120 ...
# Generating image for frame 112/120 ...
# Generating image for frame 113/120 ...
# Generating image for frame 114/120 ...
# Generating image for frame 115/120 ...
# Generating image for frame 116/120 ...
# Generating image for frame 117/120 ...
# Generating image for frame 118/120 ...
# Generating image for frame 119/120 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_noise_loop_21-d175/frames/frame%04d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f003861e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f003861e00] profile High, level 3.2
# [libx264 @ 0x55f003861e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_noise_loop_21-d175//interpolation-noiseloop-1.75dia-seed_21-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  120 fps= 20 q=-1.0 Lsize=    1604kB time=00:00:03.90 bitrate=3368.4kbits/s speed=0.654x
# video:1601kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.138794%
# [libx264 @ 0x55f003861e00] frame I:1     Avg QP:25.79  size: 46304
# [libx264 @ 0x55f003861e00] frame P:31    Avg QP:25.39  size: 27113
# [libx264 @ 0x55f003861e00] frame B:88    Avg QP:27.65  size:  8550
# [libx264 @ 0x55f003861e00] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55f003861e00] mb I  I16..4: 10.3% 68.7% 21.0%
# [libx264 @ 0x55f003861e00] mb P  I16..4:  6.1% 24.0%  3.7%  P16..4: 36.9% 14.1%  5.6%  0.0%  0.0%    skip: 9.7%
# [libx264 @ 0x55f003861e00] mb B  I16..4:  0.8%  3.0%  0.3%  B16..8: 33.3%  6.6%  1.2%  direct: 4.0%  skip:50.8%  L0:41.1% L1:49.6% BI: 9.3%
# [libx264 @ 0x55f003861e00] 8x8 transform intra:70.9% inter:77.7%
# [libx264 @ 0x55f003861e00] coded y,uvDC,uvAC intra: 62.2% 43.7% 5.4% inter: 20.1% 12.6% 0.0%
# [libx264 @ 0x55f003861e00] i16 v,h,dc,p:  8% 62%  2% 29%
# [libx264 @ 0x55f003861e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 24% 11%  6%  9%  9%  8%  9%  7%
# [libx264 @ 0x55f003861e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 23% 10%  6% 10%  8%  8%  6%  4%
# [libx264 @ 0x55f003861e00] i8c dc,h,v,p: 55% 24% 17%  5%
# [libx264 @ 0x55f003861e00] Weighted P-Frames: Y:25.8% UV:6.5%
# [libx264 @ 0x55f003861e00] ref P L0: 49.0% 26.5% 14.3%  7.8%  2.4%
# [libx264 @ 0x55f003861e00] ref B L0: 89.5%  7.1%  3.4%
# [libx264 @ 0x55f003861e00] ref B L1: 96.0%  4.0%
# [libx264 @ 0x55f003861e00] kb/s:3278.31

# %% [markdown]
# #### Circular Loop
#
# The noise loop is, well, noisy. This circular loop will feel much more even, while still providing a random loop.
#
# I recommend using a higher `--diameter` value than you do with noise loops. Something between `50.0` and `500.0` alongside `--frames` can help control speed and diversity.

# %%
# !python generate.py --outdir=./generated/kbhands_in_class-circular_d50/ --trunc=1.25 --process="interpolation" --interpolation="circularloop" --diameter=50.00 --frames=600 --fps=30 --random_seed=1000 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/600 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/600 ...
# Generating image for frame 2/600 ...
# Generating image for frame 3/600 ...
# Generating image for frame 4/600 ...
# Generating image for frame 5/600 ...
# Generating image for frame 6/600 ...
# Generating image for frame 7/600 ...
# Generating image for frame 8/600 ...
# Generating image for frame 9/600 ...
# Generating image for frame 10/600 ...
# Generating image for frame 11/600 ...
# Generating image for frame 12/600 ...
# Generating image for frame 13/600 ...
# Generating image for frame 14/600 ...
# Generating image for frame 15/600 ...
# Generating image for frame 16/600 ...
# Generating image for frame 17/600 ...
# Generating image for frame 18/600 ...
# Generating image for frame 19/600 ...
# Generating image for frame 20/600 ...
# Generating image for frame 21/600 ...
# Generating image for frame 22/600 ...
# Generating image for frame 23/600 ...
# Generating image for frame 24/600 ...
# Generating image for frame 25/600 ...
# Generating image for frame 26/600 ...
# Generating image for frame 27/600 ...
# Generating image for frame 28/600 ...
# Generating image for frame 29/600 ...
# Generating image for frame 30/600 ...
# Generating image for frame 31/600 ...
# Generating image for frame 32/600 ...
# Generating image for frame 33/600 ...
# Generating image for frame 34/600 ...
# Generating image for frame 35/600 ...
# Generating image for frame 36/600 ...
# Generating image for frame 37/600 ...
# Generating image for frame 38/600 ...
# Generating image for frame 39/600 ...
# Generating image for frame 40/600 ...
# Generating image for frame 41/600 ...
# Generating image for frame 42/600 ...
# Generating image for frame 43/600 ...
# Generating image for frame 44/600 ...
# Generating image for frame 45/600 ...
# Generating image for frame 46/600 ...
# Generating image for frame 47/600 ...
# Generating image for frame 48/600 ...
# Generating image for frame 49/600 ...
# Generating image for frame 50/600 ...
# Generating image for frame 51/600 ...
# Generating image for frame 52/600 ...
# Generating image for frame 53/600 ...
# Generating image for frame 54/600 ...
# Generating image for frame 55/600 ...
# Generating image for frame 56/600 ...
# Generating image for frame 57/600 ...
# Generating image for frame 58/600 ...
# Generating image for frame 59/600 ...
# Generating image for frame 60/600 ...
# Generating image for frame 61/600 ...
# Generating image for frame 62/600 ...
# Generating image for frame 63/600 ...
# Generating image for frame 64/600 ...
# Generating image for frame 65/600 ...
# Generating image for frame 66/600 ...
# Generating image for frame 67/600 ...
# Generating image for frame 68/600 ...
# Generating image for frame 69/600 ...
# Generating image for frame 70/600 ...
# Generating image for frame 71/600 ...
# Generating image for frame 72/600 ...
# Generating image for frame 73/600 ...
# Generating image for frame 74/600 ...
# Generating image for frame 75/600 ...
# Generating image for frame 76/600 ...
# Generating image for frame 77/600 ...
# Generating image for frame 78/600 ...
# Generating image for frame 79/600 ...
# Generating image for frame 80/600 ...
# Generating image for frame 81/600 ...
# Generating image for frame 82/600 ...
# Generating image for frame 83/600 ...
# Generating image for frame 84/600 ...
# Generating image for frame 85/600 ...
# Generating image for frame 86/600 ...
# Generating image for frame 87/600 ...
# Generating image for frame 88/600 ...
# Generating image for frame 89/600 ...
# Generating image for frame 90/600 ...
# Generating image for frame 91/600 ...
# Generating image for frame 92/600 ...
# Generating image for frame 93/600 ...
# Generating image for frame 94/600 ...
# Generating image for frame 95/600 ...
# Generating image for frame 96/600 ...
# Generating image for frame 97/600 ...
# Generating image for frame 98/600 ...
# Generating image for frame 99/600 ...
# Generating image for frame 100/600 ...
# Generating image for frame 101/600 ...
# Generating image for frame 102/600 ...
# Generating image for frame 103/600 ...
# Generating image for frame 104/600 ...
# Generating image for frame 105/600 ...
# Generating image for frame 106/600 ...
# Generating image for frame 107/600 ...
# Generating image for frame 108/600 ...
# Generating image for frame 109/600 ...
# Generating image for frame 110/600 ...
# Generating image for frame 111/600 ...
# Generating image for frame 112/600 ...
# Generating image for frame 113/600 ...
# Generating image for frame 114/600 ...
# Generating image for frame 115/600 ...
# Generating image for frame 116/600 ...
# Generating image for frame 117/600 ...
# Generating image for frame 118/600 ...
# Generating image for frame 119/600 ...
# Generating image for frame 120/600 ...
# Generating image for frame 121/600 ...
# Generating image for frame 122/600 ...
# Generating image for frame 123/600 ...
# Generating image for frame 124/600 ...
# Generating image for frame 125/600 ...
# Generating image for frame 126/600 ...
# Generating image for frame 127/600 ...
# Generating image for frame 128/600 ...
# Generating image for frame 129/600 ...
# Generating image for frame 130/600 ...
# Generating image for frame 131/600 ...
# Generating image for frame 132/600 ...
# Generating image for frame 133/600 ...
# Generating image for frame 134/600 ...
# Generating image for frame 135/600 ...
# Generating image for frame 136/600 ...
# Generating image for frame 137/600 ...
# Generating image for frame 138/600 ...
# Generating image for frame 139/600 ...
# Generating image for frame 140/600 ...
# Generating image for frame 141/600 ...
# Generating image for frame 142/600 ...
# Generating image for frame 143/600 ...
# Generating image for frame 144/600 ...
# Generating image for frame 145/600 ...
# Generating image for frame 146/600 ...
# Generating image for frame 147/600 ...
# Generating image for frame 148/600 ...
# Generating image for frame 149/600 ...
# Generating image for frame 150/600 ...
# Generating image for frame 151/600 ...
# Generating image for frame 152/600 ...
# Generating image for frame 153/600 ...
# Generating image for frame 154/600 ...
# Generating image for frame 155/600 ...
# Generating image for frame 156/600 ...
# Generating image for frame 157/600 ...
# Generating image for frame 158/600 ...
# Generating image for frame 159/600 ...
# Generating image for frame 160/600 ...
# Generating image for frame 161/600 ...
# Generating image for frame 162/600 ...
# Generating image for frame 163/600 ...
# Generating image for frame 164/600 ...
# Generating image for frame 165/600 ...
# Generating image for frame 166/600 ...
# Generating image for frame 167/600 ...
# Generating image for frame 168/600 ...
# Generating image for frame 169/600 ...
# Generating image for frame 170/600 ...
# Generating image for frame 171/600 ...
# Generating image for frame 172/600 ...
# Generating image for frame 173/600 ...
# Generating image for frame 174/600 ...
# Generating image for frame 175/600 ...
# Generating image for frame 176/600 ...
# Generating image for frame 177/600 ...
# Generating image for frame 178/600 ...
# Generating image for frame 179/600 ...
# Generating image for frame 180/600 ...
# Generating image for frame 181/600 ...
# Generating image for frame 182/600 ...
# Generating image for frame 183/600 ...
# Generating image for frame 184/600 ...
# Generating image for frame 185/600 ...
# Generating image for frame 186/600 ...
# Generating image for frame 187/600 ...
# Generating image for frame 188/600 ...
# Generating image for frame 189/600 ...
# Generating image for frame 190/600 ...
# Generating image for frame 191/600 ...
# Generating image for frame 192/600 ...
# Generating image for frame 193/600 ...
# Generating image for frame 194/600 ...
# Generating image for frame 195/600 ...
# Generating image for frame 196/600 ...
# Generating image for frame 197/600 ...
# Generating image for frame 198/600 ...
# Generating image for frame 199/600 ...
# Generating image for frame 200/600 ...
# Generating image for frame 201/600 ...
# Generating image for frame 202/600 ...
# Generating image for frame 203/600 ...
# Generating image for frame 204/600 ...
# Generating image for frame 205/600 ...
# Generating image for frame 206/600 ...
# Generating image for frame 207/600 ...
# Generating image for frame 208/600 ...
# Generating image for frame 209/600 ...
# Generating image for frame 210/600 ...
# Generating image for frame 211/600 ...
# Generating image for frame 212/600 ...
# Generating image for frame 213/600 ...
# Generating image for frame 214/600 ...
# Generating image for frame 215/600 ...
# Generating image for frame 216/600 ...
# Generating image for frame 217/600 ...
# Generating image for frame 218/600 ...
# Generating image for frame 219/600 ...
# Generating image for frame 220/600 ...
# Generating image for frame 221/600 ...
# Generating image for frame 222/600 ...
# Generating image for frame 223/600 ...
# Generating image for frame 224/600 ...
# Generating image for frame 225/600 ...
# Generating image for frame 226/600 ...
# Generating image for frame 227/600 ...
# Generating image for frame 228/600 ...
# Generating image for frame 229/600 ...
# Generating image for frame 230/600 ...
# Generating image for frame 231/600 ...
# Generating image for frame 232/600 ...
# Generating image for frame 233/600 ...
# Generating image for frame 234/600 ...
# Generating image for frame 235/600 ...
# Generating image for frame 236/600 ...
# Generating image for frame 237/600 ...
# Generating image for frame 238/600 ...
# Generating image for frame 239/600 ...
# Generating image for frame 240/600 ...
# Generating image for frame 241/600 ...
# Generating image for frame 242/600 ...
# Generating image for frame 243/600 ...
# Generating image for frame 244/600 ...
# Generating image for frame 245/600 ...
# Generating image for frame 246/600 ...
# Generating image for frame 247/600 ...
# Generating image for frame 248/600 ...
# Generating image for frame 249/600 ...
# Generating image for frame 250/600 ...
# Generating image for frame 251/600 ...
# Generating image for frame 252/600 ...
# Generating image for frame 253/600 ...
# Generating image for frame 254/600 ...
# Generating image for frame 255/600 ...
# Generating image for frame 256/600 ...
# Generating image for frame 257/600 ...
# Generating image for frame 258/600 ...
# Generating image for frame 259/600 ...
# Generating image for frame 260/600 ...
# Generating image for frame 261/600 ...
# Generating image for frame 262/600 ...
# Generating image for frame 263/600 ...
# Generating image for frame 264/600 ...
# Generating image for frame 265/600 ...
# Generating image for frame 266/600 ...
# Generating image for frame 267/600 ...
# Generating image for frame 268/600 ...
# Generating image for frame 269/600 ...
# Generating image for frame 270/600 ...
# Generating image for frame 271/600 ...
# Generating image for frame 272/600 ...
# Generating image for frame 273/600 ...
# Generating image for frame 274/600 ...
# Generating image for frame 275/600 ...
# Generating image for frame 276/600 ...
# Generating image for frame 277/600 ...
# Generating image for frame 278/600 ...
# Generating image for frame 279/600 ...
# Generating image for frame 280/600 ...
# Generating image for frame 281/600 ...
# Generating image for frame 282/600 ...
# Generating image for frame 283/600 ...
# Generating image for frame 284/600 ...
# Generating image for frame 285/600 ...
# Generating image for frame 286/600 ...
# Generating image for frame 287/600 ...
# Generating image for frame 288/600 ...
# Generating image for frame 289/600 ...
# Generating image for frame 290/600 ...
# Generating image for frame 291/600 ...
# Generating image for frame 292/600 ...
# Generating image for frame 293/600 ...
# Generating image for frame 294/600 ...
# Generating image for frame 295/600 ...
# Generating image for frame 296/600 ...
# Generating image for frame 297/600 ...
# Generating image for frame 298/600 ...
# Generating image for frame 299/600 ...
# Generating image for frame 300/600 ...
# Generating image for frame 301/600 ...
# Generating image for frame 302/600 ...
# Generating image for frame 303/600 ...
# Generating image for frame 304/600 ...
# Generating image for frame 305/600 ...
# Generating image for frame 306/600 ...
# Generating image for frame 307/600 ...
# Generating image for frame 308/600 ...
# Generating image for frame 309/600 ...
# Generating image for frame 310/600 ...
# Generating image for frame 311/600 ...
# Generating image for frame 312/600 ...
# Generating image for frame 313/600 ...
# Generating image for frame 314/600 ...
# Generating image for frame 315/600 ...
# Generating image for frame 316/600 ...
# Generating image for frame 317/600 ...
# Generating image for frame 318/600 ...
# Generating image for frame 319/600 ...
# Generating image for frame 320/600 ...
# Generating image for frame 321/600 ...
# Generating image for frame 322/600 ...
# Generating image for frame 323/600 ...
# Generating image for frame 324/600 ...
# Generating image for frame 325/600 ...
# Generating image for frame 326/600 ...
# Generating image for frame 327/600 ...
# Generating image for frame 328/600 ...
# Generating image for frame 329/600 ...
# Generating image for frame 330/600 ...
# Generating image for frame 331/600 ...
# Generating image for frame 332/600 ...
# Generating image for frame 333/600 ...
# Generating image for frame 334/600 ...
# Generating image for frame 335/600 ...
# Generating image for frame 336/600 ...
# Generating image for frame 337/600 ...
# Generating image for frame 338/600 ...
# Generating image for frame 339/600 ...
# Generating image for frame 340/600 ...
# Generating image for frame 341/600 ...
# Generating image for frame 342/600 ...
# Generating image for frame 343/600 ...
# Generating image for frame 344/600 ...
# Generating image for frame 345/600 ...
# Generating image for frame 346/600 ...
# Generating image for frame 347/600 ...
# Generating image for frame 348/600 ...
# Generating image for frame 349/600 ...
# Generating image for frame 350/600 ...
# Generating image for frame 351/600 ...
# Generating image for frame 352/600 ...
# Generating image for frame 353/600 ...
# Generating image for frame 354/600 ...
# Generating image for frame 355/600 ...
# Generating image for frame 356/600 ...
# Generating image for frame 357/600 ...
# Generating image for frame 358/600 ...
# Generating image for frame 359/600 ...
# Generating image for frame 360/600 ...
# Generating image for frame 361/600 ...
# Generating image for frame 362/600 ...
# Generating image for frame 363/600 ...
# Generating image for frame 364/600 ...
# Generating image for frame 365/600 ...
# Generating image for frame 366/600 ...
# Generating image for frame 367/600 ...
# Generating image for frame 368/600 ...
# Generating image for frame 369/600 ...
# Generating image for frame 370/600 ...
# Generating image for frame 371/600 ...
# Generating image for frame 372/600 ...
# Generating image for frame 373/600 ...
# Generating image for frame 374/600 ...
# Generating image for frame 375/600 ...
# Generating image for frame 376/600 ...
# Generating image for frame 377/600 ...
# Generating image for frame 378/600 ...
# Generating image for frame 379/600 ...
# Generating image for frame 380/600 ...
# Generating image for frame 381/600 ...
# Generating image for frame 382/600 ...
# Generating image for frame 383/600 ...
# Generating image for frame 384/600 ...
# Generating image for frame 385/600 ...
# Generating image for frame 386/600 ...
# Generating image for frame 387/600 ...
# Generating image for frame 388/600 ...
# Generating image for frame 389/600 ...
# Generating image for frame 390/600 ...
# Generating image for frame 391/600 ...
# Generating image for frame 392/600 ...
# Generating image for frame 393/600 ...
# Generating image for frame 394/600 ...
# Generating image for frame 395/600 ...
# Generating image for frame 396/600 ...
# Generating image for frame 397/600 ...
# Generating image for frame 398/600 ...
# Generating image for frame 399/600 ...
# Generating image for frame 400/600 ...
# Generating image for frame 401/600 ...
# Generating image for frame 402/600 ...
# Generating image for frame 403/600 ...
# Generating image for frame 404/600 ...
# Generating image for frame 405/600 ...
# Generating image for frame 406/600 ...
# Generating image for frame 407/600 ...
# Generating image for frame 408/600 ...
# Generating image for frame 409/600 ...
# Generating image for frame 410/600 ...
# Generating image for frame 411/600 ...
# Generating image for frame 412/600 ...
# Generating image for frame 413/600 ...
# Generating image for frame 414/600 ...
# Generating image for frame 415/600 ...
# Generating image for frame 416/600 ...
# Generating image for frame 417/600 ...
# Generating image for frame 418/600 ...
# Generating image for frame 419/600 ...
# Generating image for frame 420/600 ...
# Generating image for frame 421/600 ...
# Generating image for frame 422/600 ...
# Generating image for frame 423/600 ...
# Generating image for frame 424/600 ...
# Generating image for frame 425/600 ...
# Generating image for frame 426/600 ...
# Generating image for frame 427/600 ...
# Generating image for frame 428/600 ...
# Generating image for frame 429/600 ...
# Generating image for frame 430/600 ...
# Generating image for frame 431/600 ...
# Generating image for frame 432/600 ...
# Generating image for frame 433/600 ...
# Generating image for frame 434/600 ...
# Generating image for frame 435/600 ...
# Generating image for frame 436/600 ...
# Generating image for frame 437/600 ...
# Generating image for frame 438/600 ...
# Generating image for frame 439/600 ...
# Generating image for frame 440/600 ...
# Generating image for frame 441/600 ...
# Generating image for frame 442/600 ...
# Generating image for frame 443/600 ...
# Generating image for frame 444/600 ...
# Generating image for frame 445/600 ...
# Generating image for frame 446/600 ...
# Generating image for frame 447/600 ...
# Generating image for frame 448/600 ...
# Generating image for frame 449/600 ...
# Generating image for frame 450/600 ...
# Generating image for frame 451/600 ...
# Generating image for frame 452/600 ...
# Generating image for frame 453/600 ...
# Generating image for frame 454/600 ...
# Generating image for frame 455/600 ...
# Generating image for frame 456/600 ...
# Generating image for frame 457/600 ...
# Generating image for frame 458/600 ...
# Generating image for frame 459/600 ...
# Generating image for frame 460/600 ...
# Generating image for frame 461/600 ...
# Generating image for frame 462/600 ...
# Generating image for frame 463/600 ...
# Generating image for frame 464/600 ...
# Generating image for frame 465/600 ...
# Generating image for frame 466/600 ...
# Generating image for frame 467/600 ...
# Generating image for frame 468/600 ...
# Generating image for frame 469/600 ...
# Generating image for frame 470/600 ...
# Generating image for frame 471/600 ...
# Generating image for frame 472/600 ...
# Generating image for frame 473/600 ...
# Generating image for frame 474/600 ...
# Generating image for frame 475/600 ...
# Generating image for frame 476/600 ...
# Generating image for frame 477/600 ...
# Generating image for frame 478/600 ...
# Generating image for frame 479/600 ...
# Generating image for frame 480/600 ...
# Generating image for frame 481/600 ...
# Generating image for frame 482/600 ...
# Generating image for frame 483/600 ...
# Generating image for frame 484/600 ...
# Generating image for frame 485/600 ...
# Generating image for frame 486/600 ...
# Generating image for frame 487/600 ...
# Generating image for frame 488/600 ...
# Generating image for frame 489/600 ...
# Generating image for frame 490/600 ...
# Generating image for frame 491/600 ...
# Generating image for frame 492/600 ...
# Generating image for frame 493/600 ...
# Generating image for frame 494/600 ...
# Generating image for frame 495/600 ...
# Generating image for frame 496/600 ...
# Generating image for frame 497/600 ...
# Generating image for frame 498/600 ...
# Generating image for frame 499/600 ...
# Generating image for frame 500/600 ...
# Generating image for frame 501/600 ...
# Generating image for frame 502/600 ...
# Generating image for frame 503/600 ...
# Generating image for frame 504/600 ...
# Generating image for frame 505/600 ...
# Generating image for frame 506/600 ...
# Generating image for frame 507/600 ...
# Generating image for frame 508/600 ...
# Generating image for frame 509/600 ...
# Generating image for frame 510/600 ...
# Generating image for frame 511/600 ...
# Generating image for frame 512/600 ...
# Generating image for frame 513/600 ...
# Generating image for frame 514/600 ...
# Generating image for frame 515/600 ...
# Generating image for frame 516/600 ...
# Generating image for frame 517/600 ...
# Generating image for frame 518/600 ...
# Generating image for frame 519/600 ...
# Generating image for frame 520/600 ...
# Generating image for frame 521/600 ...
# Generating image for frame 522/600 ...
# Generating image for frame 523/600 ...
# Generating image for frame 524/600 ...
# Generating image for frame 525/600 ...
# Generating image for frame 526/600 ...
# Generating image for frame 527/600 ...
# Generating image for frame 528/600 ...
# Generating image for frame 529/600 ...
# Generating image for frame 530/600 ...
# Generating image for frame 531/600 ...
# Generating image for frame 532/600 ...
# Generating image for frame 533/600 ...
# Generating image for frame 534/600 ...
# Generating image for frame 535/600 ...
# Generating image for frame 536/600 ...
# Generating image for frame 537/600 ...
# Generating image for frame 538/600 ...
# Generating image for frame 539/600 ...
# Generating image for frame 540/600 ...
# Generating image for frame 541/600 ...
# Generating image for frame 542/600 ...
# Generating image for frame 543/600 ...
# Generating image for frame 544/600 ...
# Generating image for frame 545/600 ...
# Generating image for frame 546/600 ...
# Generating image for frame 547/600 ...
# Generating image for frame 548/600 ...
# Generating image for frame 549/600 ...
# Generating image for frame 550/600 ...
# Generating image for frame 551/600 ...
# Generating image for frame 552/600 ...
# Generating image for frame 553/600 ...
# Generating image for frame 554/600 ...
# Generating image for frame 555/600 ...
# Generating image for frame 556/600 ...
# Generating image for frame 557/600 ...
# Generating image for frame 558/600 ...
# Generating image for frame 559/600 ...
# Generating image for frame 560/600 ...
# Generating image for frame 561/600 ...
# Generating image for frame 562/600 ...
# Generating image for frame 563/600 ...
# Generating image for frame 564/600 ...
# Generating image for frame 565/600 ...
# Generating image for frame 566/600 ...
# Generating image for frame 567/600 ...
# Generating image for frame 568/600 ...
# Generating image for frame 569/600 ...
# Generating image for frame 570/600 ...
# Generating image for frame 571/600 ...
# Generating image for frame 572/600 ...
# Generating image for frame 573/600 ...
# Generating image for frame 574/600 ...
# Generating image for frame 575/600 ...
# Generating image for frame 576/600 ...
# Generating image for frame 577/600 ...
# Generating image for frame 578/600 ...
# Generating image for frame 579/600 ...
# Generating image for frame 580/600 ...
# Generating image for frame 581/600 ...
# Generating image for frame 582/600 ...
# Generating image for frame 583/600 ...
# Generating image for frame 584/600 ...
# Generating image for frame 585/600 ...
# Generating image for frame 586/600 ...
# Generating image for frame 587/600 ...
# Generating image for frame 588/600 ...
# Generating image for frame 589/600 ...
# Generating image for frame 590/600 ...
# Generating image for frame 591/600 ...
# Generating image for frame 592/600 ...
# Generating image for frame 593/600 ...
# Generating image for frame 594/600 ...
# Generating image for frame 595/600 ...
# Generating image for frame 596/600 ...
# Generating image for frame 597/600 ...
# Generating image for frame 598/600 ...
# Generating image for frame 599/600 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_in_class-circular_d50/frames/frame%04d.png':
#   Duration: 00:00:24.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x559c6063de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x559c6063de00] profile High, level 3.2
# [libx264 @ 0x559c6063de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_in_class-circular_d50//interpolation-circularloop-50.0dia-seed_1000-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  600 fps= 38 q=-1.0 Lsize=    2957kB time=00:00:19.90 bitrate=1217.1kbits/s speed=1.26x
# video:2950kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.230026%
# [libx264 @ 0x559c6063de00] frame I:3     Avg QP:20.12  size: 61378
# [libx264 @ 0x559c6063de00] frame P:257   Avg QP:21.77  size:  9016
# [libx264 @ 0x559c6063de00] frame B:340   Avg QP:26.29  size:  1526
# [libx264 @ 0x559c6063de00] consecutive B-frames: 21.3%  3.0% 19.0% 56.7%
# [libx264 @ 0x559c6063de00] mb I  I16..4: 10.6% 66.9% 22.5%
# [libx264 @ 0x559c6063de00] mb P  I16..4:  0.4%  1.8%  0.2%  P16..4: 30.6%  8.3%  5.2%  0.0%  0.0%    skip:53.5%
# [libx264 @ 0x559c6063de00] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8: 21.8%  0.6%  0.1%  direct: 0.6%  skip:76.6%  L0:19.1% L1:77.1% BI: 3.9%
# [libx264 @ 0x559c6063de00] 8x8 transform intra:72.6% inter:75.7%
# [libx264 @ 0x559c6063de00] coded y,uvDC,uvAC intra: 69.6% 50.9% 6.4% inter: 8.0% 6.5% 0.0%
# [libx264 @ 0x559c6063de00] i16 v,h,dc,p:  6% 52%  2% 40%
# [libx264 @ 0x559c6063de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 25% 12%  6%  9%  9%  8%  9%  8%
# [libx264 @ 0x559c6063de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 31%  8%  5% 10%  8%  9%  5%  5%
# [libx264 @ 0x559c6063de00] i8c dc,h,v,p: 51% 25% 17%  7%
# [libx264 @ 0x559c6063de00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559c6063de00] ref P L0: 68.5% 20.3%  9.7%  1.5%
# [libx264 @ 0x559c6063de00] ref B L0: 95.0%  4.4%  0.6%
# [libx264 @ 0x559c6063de00] ref B L1: 98.1%  1.9%
# [libx264 @ 0x559c6063de00] kb/s:1207.93

# %%
# !python generate.py --outdir=./generated/kbhands_in_class-circular_d100/ --trunc=1.25 --process="interpolation" --interpolation="circularloop" --diameter=100.00 --frames=600 --fps=30 --random_seed=1000 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl
# Out:
# Loading networks from "./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl"...
# Generating image for frame 0/600 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/600 ...
# Generating image for frame 2/600 ...
# Generating image for frame 3/600 ...
# Generating image for frame 4/600 ...
# Generating image for frame 5/600 ...
# Generating image for frame 6/600 ...
# Generating image for frame 7/600 ...
# Generating image for frame 8/600 ...
# Generating image for frame 9/600 ...
# Generating image for frame 10/600 ...
# Generating image for frame 11/600 ...
# Generating image for frame 12/600 ...
# Generating image for frame 13/600 ...
# Generating image for frame 14/600 ...
# Generating image for frame 15/600 ...
# Generating image for frame 16/600 ...
# Generating image for frame 17/600 ...
# Generating image for frame 18/600 ...
# Generating image for frame 19/600 ...
# Generating image for frame 20/600 ...
# Generating image for frame 21/600 ...
# Generating image for frame 22/600 ...
# Generating image for frame 23/600 ...
# Generating image for frame 24/600 ...
# Generating image for frame 25/600 ...
# Generating image for frame 26/600 ...
# Generating image for frame 27/600 ...
# Generating image for frame 28/600 ...
# Generating image for frame 29/600 ...
# Generating image for frame 30/600 ...
# Generating image for frame 31/600 ...
# Generating image for frame 32/600 ...
# Generating image for frame 33/600 ...
# Generating image for frame 34/600 ...
# Generating image for frame 35/600 ...
# Generating image for frame 36/600 ...
# Generating image for frame 37/600 ...
# Generating image for frame 38/600 ...
# Generating image for frame 39/600 ...
# Generating image for frame 40/600 ...
# Generating image for frame 41/600 ...
# Generating image for frame 42/600 ...
# Generating image for frame 43/600 ...
# Generating image for frame 44/600 ...
# Generating image for frame 45/600 ...
# Generating image for frame 46/600 ...
# Generating image for frame 47/600 ...
# Generating image for frame 48/600 ...
# Generating image for frame 49/600 ...
# Generating image for frame 50/600 ...
# Generating image for frame 51/600 ...
# Generating image for frame 52/600 ...
# Generating image for frame 53/600 ...
# Generating image for frame 54/600 ...
# Generating image for frame 55/600 ...
# Generating image for frame 56/600 ...
# Generating image for frame 57/600 ...
# Generating image for frame 58/600 ...
# Generating image for frame 59/600 ...
# Generating image for frame 60/600 ...
# Generating image for frame 61/600 ...
# Generating image for frame 62/600 ...
# Generating image for frame 63/600 ...
# Generating image for frame 64/600 ...
# Generating image for frame 65/600 ...
# Generating image for frame 66/600 ...
# Generating image for frame 67/600 ...
# Generating image for frame 68/600 ...
# Generating image for frame 69/600 ...
# Generating image for frame 70/600 ...
# Generating image for frame 71/600 ...
# Generating image for frame 72/600 ...
# Generating image for frame 73/600 ...
# Generating image for frame 74/600 ...
# Generating image for frame 75/600 ...
# Generating image for frame 76/600 ...
# Generating image for frame 77/600 ...
# Generating image for frame 78/600 ...
# Generating image for frame 79/600 ...
# Generating image for frame 80/600 ...
# Generating image for frame 81/600 ...
# Generating image for frame 82/600 ...
# Generating image for frame 83/600 ...
# Generating image for frame 84/600 ...
# Generating image for frame 85/600 ...
# Generating image for frame 86/600 ...
# Generating image for frame 87/600 ...
# Generating image for frame 88/600 ...
# Generating image for frame 89/600 ...
# Generating image for frame 90/600 ...
# Generating image for frame 91/600 ...
# Generating image for frame 92/600 ...
# Generating image for frame 93/600 ...
# Generating image for frame 94/600 ...
# Generating image for frame 95/600 ...
# Generating image for frame 96/600 ...
# Generating image for frame 97/600 ...
# Generating image for frame 98/600 ...
# Generating image for frame 99/600 ...
# Generating image for frame 100/600 ...
# Generating image for frame 101/600 ...
# Generating image for frame 102/600 ...
# Generating image for frame 103/600 ...
# Generating image for frame 104/600 ...
# Generating image for frame 105/600 ...
# Generating image for frame 106/600 ...
# Generating image for frame 107/600 ...
# Generating image for frame 108/600 ...
# Generating image for frame 109/600 ...
# Generating image for frame 110/600 ...
# Generating image for frame 111/600 ...
# Generating image for frame 112/600 ...
# Generating image for frame 113/600 ...
# Generating image for frame 114/600 ...
# Generating image for frame 115/600 ...
# Generating image for frame 116/600 ...
# Generating image for frame 117/600 ...
# Generating image for frame 118/600 ...
# Generating image for frame 119/600 ...
# Generating image for frame 120/600 ...
# Generating image for frame 121/600 ...
# Generating image for frame 122/600 ...
# Generating image for frame 123/600 ...
# Generating image for frame 124/600 ...
# Generating image for frame 125/600 ...
# Generating image for frame 126/600 ...
# Generating image for frame 127/600 ...
# Generating image for frame 128/600 ...
# Generating image for frame 129/600 ...
# Generating image for frame 130/600 ...
# Generating image for frame 131/600 ...
# Generating image for frame 132/600 ...
# Generating image for frame 133/600 ...
# Generating image for frame 134/600 ...
# Generating image for frame 135/600 ...
# Generating image for frame 136/600 ...
# Generating image for frame 137/600 ...
# Generating image for frame 138/600 ...
# Generating image for frame 139/600 ...
# Generating image for frame 140/600 ...
# Generating image for frame 141/600 ...
# Generating image for frame 142/600 ...
# Generating image for frame 143/600 ...
# Generating image for frame 144/600 ...
# Generating image for frame 145/600 ...
# Generating image for frame 146/600 ...
# Generating image for frame 147/600 ...
# Generating image for frame 148/600 ...
# Generating image for frame 149/600 ...
# Generating image for frame 150/600 ...
# Generating image for frame 151/600 ...
# Generating image for frame 152/600 ...
# Generating image for frame 153/600 ...
# Generating image for frame 154/600 ...
# Generating image for frame 155/600 ...
# Generating image for frame 156/600 ...
# Generating image for frame 157/600 ...
# Generating image for frame 158/600 ...
# Generating image for frame 159/600 ...
# Generating image for frame 160/600 ...
# Generating image for frame 161/600 ...
# Generating image for frame 162/600 ...
# Generating image for frame 163/600 ...
# Generating image for frame 164/600 ...
# Generating image for frame 165/600 ...
# Generating image for frame 166/600 ...
# Generating image for frame 167/600 ...
# Generating image for frame 168/600 ...
# Generating image for frame 169/600 ...
# Generating image for frame 170/600 ...
# Generating image for frame 171/600 ...
# Generating image for frame 172/600 ...
# Generating image for frame 173/600 ...
# Generating image for frame 174/600 ...
# Generating image for frame 175/600 ...
# Generating image for frame 176/600 ...
# Generating image for frame 177/600 ...
# Generating image for frame 178/600 ...
# Generating image for frame 179/600 ...
# Generating image for frame 180/600 ...
# Generating image for frame 181/600 ...
# Generating image for frame 182/600 ...
# Generating image for frame 183/600 ...
# Generating image for frame 184/600 ...
# Generating image for frame 185/600 ...
# Generating image for frame 186/600 ...
# Generating image for frame 187/600 ...
# Generating image for frame 188/600 ...
# Generating image for frame 189/600 ...
# Generating image for frame 190/600 ...
# Generating image for frame 191/600 ...
# Generating image for frame 192/600 ...
# Generating image for frame 193/600 ...
# Generating image for frame 194/600 ...
# Generating image for frame 195/600 ...
# Generating image for frame 196/600 ...
# Generating image for frame 197/600 ...
# Generating image for frame 198/600 ...
# Generating image for frame 199/600 ...
# Generating image for frame 200/600 ...
# Generating image for frame 201/600 ...
# Generating image for frame 202/600 ...
# Generating image for frame 203/600 ...
# Generating image for frame 204/600 ...
# Generating image for frame 205/600 ...
# Generating image for frame 206/600 ...
# Generating image for frame 207/600 ...
# Generating image for frame 208/600 ...
# Generating image for frame 209/600 ...
# Generating image for frame 210/600 ...
# Generating image for frame 211/600 ...
# Generating image for frame 212/600 ...
# Generating image for frame 213/600 ...
# Generating image for frame 214/600 ...
# Generating image for frame 215/600 ...
# Generating image for frame 216/600 ...
# Generating image for frame 217/600 ...
# Generating image for frame 218/600 ...
# Generating image for frame 219/600 ...
# Generating image for frame 220/600 ...
# Generating image for frame 221/600 ...
# Generating image for frame 222/600 ...
# Generating image for frame 223/600 ...
# Generating image for frame 224/600 ...
# Generating image for frame 225/600 ...
# Generating image for frame 226/600 ...
# Generating image for frame 227/600 ...
# Generating image for frame 228/600 ...
# Generating image for frame 229/600 ...
# Generating image for frame 230/600 ...
# Generating image for frame 231/600 ...
# Generating image for frame 232/600 ...
# Generating image for frame 233/600 ...
# Generating image for frame 234/600 ...
# Generating image for frame 235/600 ...
# Generating image for frame 236/600 ...
# Generating image for frame 237/600 ...
# Generating image for frame 238/600 ...
# Generating image for frame 239/600 ...
# Generating image for frame 240/600 ...
# Generating image for frame 241/600 ...
# Generating image for frame 242/600 ...
# Generating image for frame 243/600 ...
# Generating image for frame 244/600 ...
# Generating image for frame 245/600 ...
# Generating image for frame 246/600 ...
# Generating image for frame 247/600 ...
# Generating image for frame 248/600 ...
# Generating image for frame 249/600 ...
# Generating image for frame 250/600 ...
# Generating image for frame 251/600 ...
# Generating image for frame 252/600 ...
# Generating image for frame 253/600 ...
# Generating image for frame 254/600 ...
# Generating image for frame 255/600 ...
# Generating image for frame 256/600 ...
# Generating image for frame 257/600 ...
# Generating image for frame 258/600 ...
# Generating image for frame 259/600 ...
# Generating image for frame 260/600 ...
# Generating image for frame 261/600 ...
# Generating image for frame 262/600 ...
# Generating image for frame 263/600 ...
# Generating image for frame 264/600 ...
# Generating image for frame 265/600 ...
# Generating image for frame 266/600 ...
# Generating image for frame 267/600 ...
# Generating image for frame 268/600 ...
# Generating image for frame 269/600 ...
# Generating image for frame 270/600 ...
# Generating image for frame 271/600 ...
# Generating image for frame 272/600 ...
# Generating image for frame 273/600 ...
# Generating image for frame 274/600 ...
# Generating image for frame 275/600 ...
# Generating image for frame 276/600 ...
# Generating image for frame 277/600 ...
# Generating image for frame 278/600 ...
# Generating image for frame 279/600 ...
# Generating image for frame 280/600 ...
# Generating image for frame 281/600 ...
# Generating image for frame 282/600 ...
# Generating image for frame 283/600 ...
# Generating image for frame 284/600 ...
# Generating image for frame 285/600 ...
# Generating image for frame 286/600 ...
# Generating image for frame 287/600 ...
# Generating image for frame 288/600 ...
# Generating image for frame 289/600 ...
# Generating image for frame 290/600 ...
# Generating image for frame 291/600 ...
# Generating image for frame 292/600 ...
# Generating image for frame 293/600 ...
# Generating image for frame 294/600 ...
# Generating image for frame 295/600 ...
# Generating image for frame 296/600 ...
# Generating image for frame 297/600 ...
# Generating image for frame 298/600 ...
# Generating image for frame 299/600 ...
# Generating image for frame 300/600 ...
# Generating image for frame 301/600 ...
# Generating image for frame 302/600 ...
# Generating image for frame 303/600 ...
# Generating image for frame 304/600 ...
# Generating image for frame 305/600 ...
# Generating image for frame 306/600 ...
# Generating image for frame 307/600 ...
# Generating image for frame 308/600 ...
# Generating image for frame 309/600 ...
# Generating image for frame 310/600 ...
# Generating image for frame 311/600 ...
# Generating image for frame 312/600 ...
# Generating image for frame 313/600 ...
# Generating image for frame 314/600 ...
# Generating image for frame 315/600 ...
# Generating image for frame 316/600 ...
# Generating image for frame 317/600 ...
# Generating image for frame 318/600 ...
# Generating image for frame 319/600 ...
# Generating image for frame 320/600 ...
# Generating image for frame 321/600 ...
# Generating image for frame 322/600 ...
# Generating image for frame 323/600 ...
# Generating image for frame 324/600 ...
# Generating image for frame 325/600 ...
# Generating image for frame 326/600 ...
# Generating image for frame 327/600 ...
# Generating image for frame 328/600 ...
# Generating image for frame 329/600 ...
# Generating image for frame 330/600 ...
# Generating image for frame 331/600 ...
# Generating image for frame 332/600 ...
# Generating image for frame 333/600 ...
# Generating image for frame 334/600 ...
# Generating image for frame 335/600 ...
# Generating image for frame 336/600 ...
# Generating image for frame 337/600 ...
# Generating image for frame 338/600 ...
# Generating image for frame 339/600 ...
# Generating image for frame 340/600 ...
# Generating image for frame 341/600 ...
# Generating image for frame 342/600 ...
# Generating image for frame 343/600 ...
# Generating image for frame 344/600 ...
# Generating image for frame 345/600 ...
# Generating image for frame 346/600 ...
# Generating image for frame 347/600 ...
# Generating image for frame 348/600 ...
# Generating image for frame 349/600 ...
# Generating image for frame 350/600 ...
# Generating image for frame 351/600 ...
# Generating image for frame 352/600 ...
# Generating image for frame 353/600 ...
# Generating image for frame 354/600 ...
# Generating image for frame 355/600 ...
# Generating image for frame 356/600 ...
# Generating image for frame 357/600 ...
# Generating image for frame 358/600 ...
# Generating image for frame 359/600 ...
# Generating image for frame 360/600 ...
# Generating image for frame 361/600 ...
# Generating image for frame 362/600 ...
# Generating image for frame 363/600 ...
# Generating image for frame 364/600 ...
# Generating image for frame 365/600 ...
# Generating image for frame 366/600 ...
# Generating image for frame 367/600 ...
# Generating image for frame 368/600 ...
# Generating image for frame 369/600 ...
# Generating image for frame 370/600 ...
# Generating image for frame 371/600 ...
# Generating image for frame 372/600 ...
# Generating image for frame 373/600 ...
# Generating image for frame 374/600 ...
# Generating image for frame 375/600 ...
# Generating image for frame 376/600 ...
# Generating image for frame 377/600 ...
# Generating image for frame 378/600 ...
# Generating image for frame 379/600 ...
# Generating image for frame 380/600 ...
# Generating image for frame 381/600 ...
# Generating image for frame 382/600 ...
# Generating image for frame 383/600 ...
# Generating image for frame 384/600 ...
# Generating image for frame 385/600 ...
# Generating image for frame 386/600 ...
# Generating image for frame 387/600 ...
# Generating image for frame 388/600 ...
# Generating image for frame 389/600 ...
# Generating image for frame 390/600 ...
# Generating image for frame 391/600 ...
# Generating image for frame 392/600 ...
# Generating image for frame 393/600 ...
# Generating image for frame 394/600 ...
# Generating image for frame 395/600 ...
# Generating image for frame 396/600 ...
# Generating image for frame 397/600 ...
# Generating image for frame 398/600 ...
# Generating image for frame 399/600 ...
# Generating image for frame 400/600 ...
# Generating image for frame 401/600 ...
# Generating image for frame 402/600 ...
# Generating image for frame 403/600 ...
# Generating image for frame 404/600 ...
# Generating image for frame 405/600 ...
# Generating image for frame 406/600 ...
# Generating image for frame 407/600 ...
# Generating image for frame 408/600 ...
# Generating image for frame 409/600 ...
# Generating image for frame 410/600 ...
# Generating image for frame 411/600 ...
# Generating image for frame 412/600 ...
# Generating image for frame 413/600 ...
# Generating image for frame 414/600 ...
# Generating image for frame 415/600 ...
# Generating image for frame 416/600 ...
# Generating image for frame 417/600 ...
# Generating image for frame 418/600 ...
# Generating image for frame 419/600 ...
# Generating image for frame 420/600 ...
# Generating image for frame 421/600 ...
# Generating image for frame 422/600 ...
# Generating image for frame 423/600 ...
# Generating image for frame 424/600 ...
# Generating image for frame 425/600 ...
# Generating image for frame 426/600 ...
# Generating image for frame 427/600 ...
# Generating image for frame 428/600 ...
# Generating image for frame 429/600 ...
# Generating image for frame 430/600 ...
# Generating image for frame 431/600 ...
# Generating image for frame 432/600 ...
# Generating image for frame 433/600 ...
# Generating image for frame 434/600 ...
# Generating image for frame 435/600 ...
# Generating image for frame 436/600 ...
# Generating image for frame 437/600 ...
# Generating image for frame 438/600 ...
# Generating image for frame 439/600 ...
# Generating image for frame 440/600 ...
# Generating image for frame 441/600 ...
# Generating image for frame 442/600 ...
# Generating image for frame 443/600 ...
# Generating image for frame 444/600 ...
# Generating image for frame 445/600 ...
# Generating image for frame 446/600 ...
# Generating image for frame 447/600 ...
# Generating image for frame 448/600 ...
# Generating image for frame 449/600 ...
# Generating image for frame 450/600 ...
# Generating image for frame 451/600 ...
# Generating image for frame 452/600 ...
# Generating image for frame 453/600 ...
# Generating image for frame 454/600 ...
# Generating image for frame 455/600 ...
# Generating image for frame 456/600 ...
# Generating image for frame 457/600 ...
# Generating image for frame 458/600 ...
# Generating image for frame 459/600 ...
# Generating image for frame 460/600 ...
# Generating image for frame 461/600 ...
# Generating image for frame 462/600 ...
# Generating image for frame 463/600 ...
# Generating image for frame 464/600 ...
# Generating image for frame 465/600 ...
# Generating image for frame 466/600 ...
# Generating image for frame 467/600 ...
# Generating image for frame 468/600 ...
# Generating image for frame 469/600 ...
# Generating image for frame 470/600 ...
# Generating image for frame 471/600 ...
# Generating image for frame 472/600 ...
# Generating image for frame 473/600 ...
# Generating image for frame 474/600 ...
# Generating image for frame 475/600 ...
# Generating image for frame 476/600 ...
# Generating image for frame 477/600 ...
# Generating image for frame 478/600 ...
# Generating image for frame 479/600 ...
# Generating image for frame 480/600 ...
# Generating image for frame 481/600 ...
# Generating image for frame 482/600 ...
# Generating image for frame 483/600 ...
# Generating image for frame 484/600 ...
# Generating image for frame 485/600 ...
# Generating image for frame 486/600 ...
# Generating image for frame 487/600 ...
# Generating image for frame 488/600 ...
# Generating image for frame 489/600 ...
# Generating image for frame 490/600 ...
# Generating image for frame 491/600 ...
# Generating image for frame 492/600 ...
# Generating image for frame 493/600 ...
# Generating image for frame 494/600 ...
# Generating image for frame 495/600 ...
# Generating image for frame 496/600 ...
# Generating image for frame 497/600 ...
# Generating image for frame 498/600 ...
# Generating image for frame 499/600 ...
# Generating image for frame 500/600 ...
# Generating image for frame 501/600 ...
# Generating image for frame 502/600 ...
# Generating image for frame 503/600 ...
# Generating image for frame 504/600 ...
# Generating image for frame 505/600 ...
# Generating image for frame 506/600 ...
# Generating image for frame 507/600 ...
# Generating image for frame 508/600 ...
# Generating image for frame 509/600 ...
# Generating image for frame 510/600 ...
# Generating image for frame 511/600 ...
# Generating image for frame 512/600 ...
# Generating image for frame 513/600 ...
# Generating image for frame 514/600 ...
# Generating image for frame 515/600 ...
# Generating image for frame 516/600 ...
# Generating image for frame 517/600 ...
# Generating image for frame 518/600 ...
# Generating image for frame 519/600 ...
# Generating image for frame 520/600 ...
# Generating image for frame 521/600 ...
# Generating image for frame 522/600 ...
# Generating image for frame 523/600 ...
# Generating image for frame 524/600 ...
# Generating image for frame 525/600 ...
# Generating image for frame 526/600 ...
# Generating image for frame 527/600 ...
# Generating image for frame 528/600 ...
# Generating image for frame 529/600 ...
# Generating image for frame 530/600 ...
# Generating image for frame 531/600 ...
# Generating image for frame 532/600 ...
# Generating image for frame 533/600 ...
# Generating image for frame 534/600 ...
# Generating image for frame 535/600 ...
# Generating image for frame 536/600 ...
# Generating image for frame 537/600 ...
# Generating image for frame 538/600 ...
# Generating image for frame 539/600 ...
# Generating image for frame 540/600 ...
# Generating image for frame 541/600 ...
# Generating image for frame 542/600 ...
# Generating image for frame 543/600 ...
# Generating image for frame 544/600 ...
# Generating image for frame 545/600 ...
# Generating image for frame 546/600 ...
# Generating image for frame 547/600 ...
# Generating image for frame 548/600 ...
# Generating image for frame 549/600 ...
# Generating image for frame 550/600 ...
# Generating image for frame 551/600 ...
# Generating image for frame 552/600 ...
# Generating image for frame 553/600 ...
# Generating image for frame 554/600 ...
# Generating image for frame 555/600 ...
# Generating image for frame 556/600 ...
# Generating image for frame 557/600 ...
# Generating image for frame 558/600 ...
# Generating image for frame 559/600 ...
# Generating image for frame 560/600 ...
# Generating image for frame 561/600 ...
# Generating image for frame 562/600 ...
# Generating image for frame 563/600 ...
# Generating image for frame 564/600 ...
# Generating image for frame 565/600 ...
# Generating image for frame 566/600 ...
# Generating image for frame 567/600 ...
# Generating image for frame 568/600 ...
# Generating image for frame 569/600 ...
# Generating image for frame 570/600 ...
# Generating image for frame 571/600 ...
# Generating image for frame 572/600 ...
# Generating image for frame 573/600 ...
# Generating image for frame 574/600 ...
# Generating image for frame 575/600 ...
# Generating image for frame 576/600 ...
# Generating image for frame 577/600 ...
# Generating image for frame 578/600 ...
# Generating image for frame 579/600 ...
# Generating image for frame 580/600 ...
# Generating image for frame 581/600 ...
# Generating image for frame 582/600 ...
# Generating image for frame 583/600 ...
# Generating image for frame 584/600 ...
# Generating image for frame 585/600 ...
# Generating image for frame 586/600 ...
# Generating image for frame 587/600 ...
# Generating image for frame 588/600 ...
# Generating image for frame 589/600 ...
# Generating image for frame 590/600 ...
# Generating image for frame 591/600 ...
# Generating image for frame 592/600 ...
# Generating image for frame 593/600 ...
# Generating image for frame 594/600 ...
# Generating image for frame 595/600 ...
# Generating image for frame 596/600 ...
# Generating image for frame 597/600 ...
# Generating image for frame 598/600 ...
# Generating image for frame 599/600 ...
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from './generated/kbhands_in_class-circular_d100/frames/frame%04d.png':
#   Duration: 00:00:24.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f97d225e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f97d225e00] profile High, level 3.2
# [libx264 @ 0x55f97d225e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './generated/kbhands_in_class-circular_d100//interpolation-circularloop-100.0dia-seed_1000-30fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  600 fps= 36 q=-1.0 Lsize=    3080kB time=00:00:19.90 bitrate=1268.1kbits/s speed= 1.2x
# video:3073kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.231968%
# [libx264 @ 0x55f97d225e00] frame I:3     Avg QP:20.88  size: 69602
# [libx264 @ 0x55f97d225e00] frame P:212   Avg QP:21.93  size: 11613
# [libx264 @ 0x55f97d225e00] frame B:385   Avg QP:25.80  size:  1235
# [libx264 @ 0x55f97d225e00] consecutive B-frames: 10.5%  1.3% 31.5% 56.7%
# [libx264 @ 0x55f97d225e00] mb I  I16..4:  8.1% 68.1% 23.8%
# [libx264 @ 0x55f97d225e00] mb P  I16..4:  0.3%  1.4%  0.2%  P16..4: 36.1% 11.2%  6.8%  0.0%  0.0%    skip:44.0%
# [libx264 @ 0x55f97d225e00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 22.5%  0.5%  0.1%  direct: 0.3%  skip:76.5%  L0:16.3% L1:80.9% BI: 2.8%
# [libx264 @ 0x55f97d225e00] 8x8 transform intra:71.0% inter:73.3%
# [libx264 @ 0x55f97d225e00] coded y,uvDC,uvAC intra: 72.8% 52.8% 9.5% inter: 8.3% 6.4% 0.0%
# [libx264 @ 0x55f97d225e00] i16 v,h,dc,p:  9% 51%  3% 37%
# [libx264 @ 0x55f97d225e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 22% 11%  5%  9%  9%  9%  9%  7%
# [libx264 @ 0x55f97d225e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 28%  8%  5% 10%  8%  9%  5%  5%
# [libx264 @ 0x55f97d225e00] i8c dc,h,v,p: 51% 24% 19%  6%
# [libx264 @ 0x55f97d225e00] Weighted P-Frames: Y:0.9% UV:0.0%
# [libx264 @ 0x55f97d225e00] ref P L0: 67.7% 19.8% 10.8%  1.7%  0.0%
# [libx264 @ 0x55f97d225e00] ref B L0: 93.9%  5.5%  0.7%
# [libx264 @ 0x55f97d225e00] ref B L1: 98.5%  1.5%
# [libx264 @ 0x55f97d225e00] kb/s:1258.52

# %%
# !python generate.py --outdir=./generated/kbhands_in_class-circular_d200/ --trunc=1.25 --process="interpolation" --interpolation="circularloop" --diameter=200.00 --frames=600 --fps=30 --random_seed=1000 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %%
# !python generate.py --outdir=./generated/kbhands_in_class-circular_d400/ --trunc=1.25 --process="interpolation" --interpolation="circularloop" --diameter=400.00 --frames=600 --fps=30 --random_seed=1000 --network=./results/00002-keyboard_hands-1024-mirror-11gb-gpu-gamma50-bg-resumecustom/network-snapshot-000138.pkl

# %% [markdown]
# # Projection
# Project images into the latent space

# %%
# !python projector.py --outdir=./generated/projection/output/doug1 --target=./generated/projection/input/doug1.png --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl ... done
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metrics/vgg16.pt ... done
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.60 loss 24567.15
# step    2/1000: dist 0.53 loss 27640.43
# step    3/1000: dist 0.58 loss 27166.95
# step    4/1000: dist 0.55 loss 26253.05
# step    5/1000: dist 0.55 loss 24956.84
# step    6/1000: dist 0.54 loss 23353.68
# step    7/1000: dist 0.53 loss 21512.43
# step    8/1000: dist 0.55 loss 19485.85
# step    9/1000: dist 0.58 loss 17339.16
# step   10/1000: dist 0.46 loss 15139.33
# step   11/1000: dist 0.49 loss 12948.90
# step   12/1000: dist 0.50 loss 10818.31
# step   13/1000: dist 0.55 loss 8801.96
# step   14/1000: dist 0.47 loss 6945.81
# step   15/1000: dist 0.48 loss 5315.13
# step   16/1000: dist 0.46 loss 3970.76
# step   17/1000: dist 0.46 loss 2943.90
# step   18/1000: dist 0.45 loss 2215.00
# step   19/1000: dist 0.46 loss 1759.53
# step   20/1000: dist 0.41 loss 1566.53
# step   21/1000: dist 0.42 loss 1602.48
# step   22/1000: dist 0.39 loss 1787.50
# step   23/1000: dist 0.39 loss 2052.95
# step   24/1000: dist 0.37 loss 2328.81
# step   25/1000: dist 0.40 loss 2537.78
# step   26/1000: dist 0.35 loss 2636.73
# step   27/1000: dist 0.33 loss 2605.24
# step   28/1000: dist 0.28 loss 2475.39
# step   29/1000: dist 0.26 loss 2314.10
# step   30/1000: dist 0.30 loss 2122.11
# step   31/1000: dist 0.29 loss 1881.49
# step   32/1000: dist 0.30 loss 1621.16
# step   33/1000: dist 0.27 loss 1383.49
# step   34/1000: dist 0.27 loss 1183.10
# step   35/1000: dist 0.27 loss 1025.17
# step   36/1000: dist 0.29 loss 906.09
# step   37/1000: dist 0.27 loss 829.24
# step   38/1000: dist 0.26 loss 817.42
# step   39/1000: dist 0.24 loss 831.65
# step   40/1000: dist 0.23 loss 839.76
# step   41/1000: dist 0.25 loss 838.55
# step   42/1000: dist 0.24 loss 774.83
# step   43/1000: dist 0.24 loss 652.94
# step   44/1000: dist 0.24 loss 534.07
# step   45/1000: dist 0.25 loss 408.69
# step   46/1000: dist 0.25 loss 319.24
# step   47/1000: dist 0.23 loss 268.61
# step   48/1000: dist 0.24 loss 242.71
# step   49/1000: dist 0.22 loss 260.95
# step   50/1000: dist 0.24 loss 308.77
# step   51/1000: dist 0.27 loss 370.94
# step   52/1000: dist 0.28 loss 401.84
# step   53/1000: dist 0.25 loss 382.89
# step   54/1000: dist 0.23 loss 352.37
# step   55/1000: dist 0.24 loss 287.29
# step   56/1000: dist 0.26 loss 194.09
# step   57/1000: dist 0.23 loss 128.56
# step   58/1000: dist 0.24 loss 81.74
# step   59/1000: dist 0.22 loss 53.49
# step   60/1000: dist 0.24 loss 53.27
# step   61/1000: dist 0.23 loss 62.75
# step   62/1000: dist 0.24 loss 83.41
# step   63/1000: dist 0.25 loss 114.47
# step   64/1000: dist 0.21 loss 125.37
# step   65/1000: dist 0.22 loss 127.45
# step   66/1000: dist 0.24 loss 119.74
# step   67/1000: dist 0.24 loss 95.96
# step   68/1000: dist 0.23 loss 72.14
# step   69/1000: dist 0.22 loss 47.82
# step   70/1000: dist 0.22 loss 28.22
# step   71/1000: dist 0.21 loss 18.73
# step   72/1000: dist 0.23 loss 16.03
# step   73/1000: dist 0.22 loss 21.40
# step   74/1000: dist 0.23 loss 25.85
# step   75/1000: dist 0.22 loss 32.85
# step   76/1000: dist 0.21 loss 35.67
# step   77/1000: dist 0.21 loss 32.39
# step   78/1000: dist 0.21 loss 30.32
# step   79/1000: dist 0.22 loss 27.39
# step   80/1000: dist 0.23 loss 25.72
# step   81/1000: dist 0.22 loss 22.26
# step   82/1000: dist 0.22 loss 14.37
# step   83/1000: dist 0.22 loss 11.01
# step   84/1000: dist 0.21 loss 13.56
# step   85/1000: dist 0.22 loss 16.18
# step   86/1000: dist 0.21 loss 13.97
# step   87/1000: dist 0.22 loss 12.16
# step   88/1000: dist 0.22 loss 13.65
# step   89/1000: dist 0.24 loss 12.74
# step   90/1000: dist 0.22 loss 10.11
# step   91/1000: dist 0.21 loss 8.57
# step   92/1000: dist 0.21 loss 7.70
# step   93/1000: dist 0.20 loss 9.05
# step   94/1000: dist 0.22 loss 12.55
# step   95/1000: dist 0.23 loss 16.23
# step   96/1000: dist 0.20 loss 18.01
# step   97/1000: dist 0.21 loss 14.62
# step   98/1000: dist 0.22 loss 8.29
# step   99/1000: dist 0.22 loss 5.10
# step  100/1000: dist 0.22 loss 6.45
# step  101/1000: dist 0.21 loss 9.45
# step  102/1000: dist 0.24 loss 9.86
# step  103/1000: dist 0.20 loss 7.12
# step  104/1000: dist 0.22 loss 5.51
# step  105/1000: dist 0.20 loss 6.13
# step  106/1000: dist 0.19 loss 6.44
